# %% [markdown]
# 掛接雲端硬碟

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %% [markdown]
# # Part 1: Network Training
# This tutorial demonstrates how to train the FNN-based model for the core loss prediction. The network model will be trained based on Dataset_tri.json and saved as a state dictionary (.sd) file.

# %% [markdown]
# # Step 0: Import Packages
# In this demo, the neural network is synthesized using the PyTorch framework. Please install PyTorch according to the [official guidance](https://pytorch.org/get-started/locally/) , then import PyTorch and other dependent modules.

# %%
# Import necessary packages


import torch
from torch import Tensor
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import random
import numpy as np
import json
import math
import csv
from pathlib import Path

# %% [markdown]
# # Step 1: Define Network Structure
# In this part, we define the structure of the feedforward neural network. Refer to the [PyTorch document](https://pytorch.org/tutorials/beginner/blitz/neural_networks_tutorial.html) for more details.
# ![image.png](data:image/png;base64,...)

# %%
# Define model structures and functions

class Net(nn.Module):
    def __init__(self, load_pretrained: bool = False, pretrained_model_path :str  = "None"):
        super(Net, self).__init__()
        # Define a fully connected layers model with three inputs (frequency, flux density, duty ratio) and one output (power loss).
        self.layers = nn.Sequential(
            nn.Linear(1026, 65),
            nn.ReLU(),
            nn.Linear(65, 55),
            nn.ReLU(),
            nn.Linear(55, 116),
            nn.ReLU(),
            nn.Linear(116, 40),
            nn.ReLU(),
            nn.Linear(40, 123),
            nn.ReLU(),
            nn.Linear(123, 1),
        )
        if load_pretrained and pretrained_model_path is not None:
          self.load_pretrained_model(pretrained_model_path)

    def forward(self, x):
        return self.layers(x)

    def load_pretrained_model(self, path):
      # 讀取並設置預訓練模型的權重
      pretrained_dict = torch.load(path)
      # 獲取當前模型的狀態字典
      model_dict = self.state_dict()
      # 更新當前模型的狀態字典中的權重
      model_dict.update(pretrained_dict)
      # 更新模型字典以匹配預訓練模型的字典
      self.load_state_dict(model_dict)
      print('Model is load')


def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# # Step 2: Load the Dataset
# In this part, we load and pre-process the dataset for the network training and testing. In this demo, a small dataset containing triangular waveforms measured with Material Brrite material under different frequency, flux density, and duty ratio is used, which can be downloaded from the [MagNet GitHub](https://github.com/PrincetonUniversity/Magnet) repository under "tutorial".

# %%
# Load the dataset

material_name = 'N49'
# material_b_mix

# B_file_path = f'/content/drive/MyDrive/Colab_Notebooks/MagNet/Database/{material_name}/B_Field.csv'
B_file_path = f'/content/drive/MyDrive/Colab_Notebooks/MagNet/Database/{material_name}/B_waveform.csv'
Freq_file_path = f'/content/drive/MyDrive/Colab_Notebooks/MagNet/Database/{material_name}/Frequency.csv'
Temp_file_path = f'/content/drive/MyDrive/Colab_Notebooks/MagNet/Database/{material_name}/Temperature.csv'
Power_file_path = f'/content/drive/MyDrive/Colab_Notebooks/MagNet/Database/{material_name}/Volumetric_Loss.csv'

# Pre-Train
pretrain_model_path = f'/content/drive/MyDrive/Colab_Notebooks/MagNet/Final_test/FNN/Model/Test_Split/spilt622/Model_3E6_77_78_N30_optuna2_NoPretrain.sd'
Transfer_use = False
Pretrain = 'NoPretrain' #Pretrain/NoPretrain
spilt_way = 'spilt622' #spilt622/spilt2/midterm_material

# Output
output_sd_path = f'/content/drive/MyDrive/Colab_Notebooks/MagNet/Final_test/FNN/Model/Test_Split/{spilt_way}/Model_{material_name}_optuna2_{Pretrain}.sd'
output_pred_path = f'/content/drive/MyDrive/Colab_Notebooks/MagNet/Final_test/FNN/Loss/withoutH_Transfer/{spilt_way}/pred_loss_{material_name}_optuna2_{Pretrain}.csv'

def get_dataset():

    B = read_csv(B_file_path)
    Freq = read_csv(Freq_file_path)
    Temp = read_csv(Temp_file_path)
    #H = read_csv(H_file_path)
    Power = read_csv(Power_file_path)

    # Compute labels
    # There's approximalely an exponential relationship between Loss-Freq and Loss-Flux.
    # Using logarithm may help to improve the training.
    Freq = np.log10(Freq)
    Temp = np.array(Temp)
    Power = np.log10(Power)

    # Reshape data
    Freq = torch.from_numpy(Freq).float().view(-1, 1)
    B = torch.from_numpy(B).float().view((-1,1024,1))
    #H = torch.from_numpy(H).float().view((-1,1024,1))
    Temp = torch.from_numpy(Temp).view(-1, 1)
    Power = Power.reshape((-1,1))

    # Normalize
    B = (B-torch.mean(B))/torch.std(B).numpy()
    #H = (H-torch.mean(H))/torch.std(H).numpy()
    Freq = (Freq-torch.mean(Freq))/torch.std(Freq).numpy()
    Temp = (Temp-torch.mean(Temp))/torch.std(Temp).numpy()

    B = np.squeeze(B, axis=2)
    #H = np.squeeze(H, axis=2)

    print(np.shape(Freq))
    print(np.shape(B))
    #print(np.shape(H))
    print(np.shape(Temp))
    print(np.shape(Power))

    temp = np.concatenate((Freq,B,Temp),axis=1)

    in_tensors = torch.from_numpy(temp).view(-1, 1026)
    out_tensors = torch.from_numpy(Power).view(-1, 1)

    return torch.utils.data.TensorDataset(in_tensors, out_tensors)

def read_csv(file_path):
    data = []
    with open(file_path, 'r', newline='') as file:
        csv_reader = csv.reader(file)
        for row in csv_reader:
            values = [float(value) for value in row]
            data.append(values)
    return np.array(data)

# %% [markdown]
# # Step 3: Training and Testing the Model
# In this part, we program the training and testing procedure of the network model. The loaded dataset is randomly split into training set, validation set, and test set. The output of the training is the state dictionary file (.sd) containing all the trained parameter values.

# %%
# Config the model training

def main():
    # Reproducibility
    random.seed(1)
    np.random.seed(1)
    torch.manual_seed(1)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    # Hyperparameters
    NUM_EPOCH = 2000
    BATCH_SIZE = 128
    DECAY_EPOCH = 423
    DECAY_RATIO = 0.458
    LR_INI = 0.005
    best_loss = math.inf
    early_stop_count = 0
    early_stop = 500
    # Select GPU as default device
    device = torch.device("cuda")

    # Load dataset
    dataset = get_dataset()

    train_size = int(0.8 * len(dataset))
    train_size = int(0.6 * len(dataset))
    valid_size = int(0.2 * len(dataset))
    test_size = len(dataset) - train_size - valid_size
    train_dataset, valid_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, valid_size, test_size])
    kwargs = {'num_workers': 0, 'pin_memory': True, 'pin_memory_device': "cuda"}
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, **kwargs)
    valid_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=BATCH_SIZE, shuffle=False, **kwargs)
    test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, **kwargs)

    # Setup network
    # net = Net().double().to(device)
    net = Net(Transfer_use ,pretrain_model_path).double().to(device)

    # Log the number of parameters
    print("Number of parameters: ", count_parameters(net))

    # Setup optimizer
    criterion = nn.MSELoss()
    optimizer = optim.Adam(net.parameters(), lr=LR_INI)

    # Train the network
    for epoch_i in range(NUM_EPOCH):

        # Train for one epoch
        epoch_train_loss = 0
        net.train()
        optimizer.param_groups[0]['lr'] = LR_INI* (DECAY_RATIO ** (0+ epoch_i // DECAY_EPOCH))

        for inputs, labels in train_loader:
            optimizer.zero_grad()
            outputs = net(inputs.to(device))
            loss = criterion(outputs, labels.to(device))
            loss.backward()
            optimizer.step()
            epoch_train_loss += loss.item()

        # Compute Validation Loss
        with torch.no_grad():
            epoch_valid_loss = 0
            for inputs, labels in valid_loader:
                outputs = net(inputs.to(device))
                loss = criterion(outputs, labels.to(device))

                epoch_valid_loss += loss.item()

        if (epoch_i+1)%5 == 0:
          print(f"Epoch {epoch_i+1:2d} "
              f"Train {epoch_train_loss / len(train_dataset) * 1e5:.5f} "
              f"Valid {epoch_valid_loss / len(valid_dataset) * 1e5:.5f}")

        # Early stop
        epoch_valid_loss = epoch_valid_loss / len(valid_dataset) * 1e5
        if epoch_valid_loss < best_loss:
          best_loss = epoch_valid_loss
          torch.save(net.state_dict(), output_sd_path)
          print('Saving model with loss {:.3f}...'.format(best_loss))
          early_stop_count = 0
        else:
          early_stop_count += 1

        if early_stop_count >= early_stop:
          print('Model is not improving, so we halt the training session.')
          break
    print("Training finished! Model is saved!")


    # Load the best model  ====================================================
    net.load_state_dict(torch.load(output_sd_path))
    print("Best model is load to test")
    # =====================================================================

    # Evaluation
    net.eval()
    y_meas = []
    y_pred = []
    with torch.no_grad():
            y_pred.append(net(inputs.to(device)))
            y_meas.append(labels.to(device))

    y_meas = torch.cat(y_meas, dim=0)
    y_pred = torch.cat(y_pred, dim=0)
    print(f"Test Loss: {F.mse_loss(y_meas, y_pred).item() / len(test_dataset) * 1e5:.5f}")

    yy_pred = 10**(y_pred.cpu().numpy())
    yy_meas = 10**(y_meas.cpu().numpy())
    print("yy_pred :", yy_pred.shape)
    print("yy_meas :", yy_meas.shape)

    with open(output_pred_path, "w") as f:
        np.savetxt(f, (yy_pred))
        f.close()
    #with open("/content/drive/MyDrive/材料/Material B/Pred_loss/meas_loss_Material B_optuna3.csv", "w") as f:
        #np.savetxt(f, (yy_meas))
        #f.close()

    # Relative Error
    Error_re = abs(yy_pred-yy_meas)/abs(yy_meas)*100
    Error_re_avg = np.mean(Error_re)
    Error_re_rms = np.sqrt(np.mean(Error_re ** 2))
    Error_re_95prct = np.percentile(Error_re, 95)
    Error_re_99prct = np.percentile(Error_re, 99)
    Error_re_max = np.max(Error_re)

    print(f"Relative Error: {Error_re_avg:.8f}")
    print(f"AVG Error: {Error_re_avg:.8f}")
    # print(f"RMS Error: {Error_re_rms:.8f}")
    print(f"95-PRCT Error: {Error_re_95prct:.8f}")
    print(f"99th Percentile Error: {Error_re_99prct:.8f}")
    print(f"MAX Error: {Error_re_max:.8f}")


if __name__ == "__main__":
    main()
# Out:
# torch.Size([5000, 1])
# torch.Size([5000, 1024])
# torch.Size([5000, 1])
# (5000, 1)
# Number of parameters:  86728
# Saving model with loss 3481.507...
# Saving model with loss 1450.607...
# Saving model with loss 178.980...
# Saving model with loss 115.255...
# Epoch  5 Train 106.73667 Valid 98.20437
# Saving model with loss 98.204...
# Saving model with loss 89.694...
# Saving model with loss 86.885...
# Saving model with loss 84.798...
# Saving model with loss 60.291...
# Epoch 10 Train 56.02172 Valid 49.97248
# Saving model with loss 49.972...
# Saving model with loss 39.286...
# Saving model with loss 24.745...
# Saving model with loss 16.098...
# Epoch 15 Train 22.60598 Valid 9.68722
# Saving model with loss 9.687...
# Epoch 20 Train 8.51619 Valid 8.36950
# Saving model with loss 8.370...
# Saving model with loss 5.923...
# Saving model with loss 5.592...
# Epoch 25 Train 8.82550 Valid 5.12979
# Saving model with loss 5.130...
# Epoch 30 Train 9.24650 Valid 7.12181
# Epoch 35 Train 11.69200 Valid 8.84152
# Saving model with loss 4.351...
# Epoch 40 Train 4.41967 Valid 3.98184
# Saving model with loss 3.982...
# Saving model with loss 3.693...
# Epoch 45 Train 12.40743 Valid 6.62030
# Epoch 50 Train 6.67852 Valid 4.75933
# Saving model with loss 3.498...
# Epoch 55 Train 6.76010 Valid 9.07680
# Epoch 60 Train 4.02382 Valid 3.98459
# Saving model with loss 2.558...
# Epoch 65 Train 2.80695 Valid 4.33531
# Saving model with loss 2.330...
# Epoch 70 Train 4.36436 Valid 13.46211
# Saving model with loss 2.148...
# Epoch 75 Train 4.69251 Valid 9.40463
# Saving model with loss 2.136...
# Epoch 80 Train 2.92579 Valid 2.98595
# Saving model with loss 1.871...
# Epoch 85 Train 3.66699 Valid 7.80906
# Epoch 90 Train 2.25730 Valid 11.15286
# Epoch 95 Train 2.06174 Valid 1.74894
# Saving model with loss 1.749...
# Epoch 100 Train 2.38860 Valid 11.56811
# Epoch 105 Train 3.76663 Valid 9.86797
# Saving model with loss 1.315...
# Epoch 110 Train 4.41109 Valid 10.92560
# Epoch 115 Train 1.32892 Valid 1.92055
# Epoch 120 Train 2.77332 Valid 3.21212
# Epoch 125 Train 3.87684 Valid 4.84059
# Epoch 130 Train 4.02646 Valid 1.83984
# Saving model with loss 1.145...
# Epoch 135 Train 2.75017 Valid 1.26004
# Epoch 140 Train 4.76805 Valid 2.49594
# Epoch 145 Train 18.24497 Valid 10.28760
# Saving model with loss 1.077...
# Epoch 150 Train 1.07698 Valid 1.59345
# Epoch 155 Train 1.41585 Valid 1.16638
# Saving model with loss 1.014...
# Epoch 160 Train 1.75878 Valid 4.19210
# Epoch 165 Train 5.86902 Valid 3.31208
# Epoch 170 Train 3.28496 Valid 4.42903
# Epoch 175 Train 2.13668 Valid 2.33143
# Epoch 180 Train 2.38938 Valid 2.83574
# Epoch 185 Train 1.06211 Valid 1.44247
# Epoch 190 Train 3.70982 Valid 2.58052
# Epoch 195 Train 1.70011 Valid 1.02596
# Epoch 200 Train 1.86369 Valid 1.37877
# Epoch 205 Train 3.07232 Valid 4.17396
# Epoch 210 Train 2.36944 Valid 2.21613
# Epoch 215 Train 1.07111 Valid 1.94465
# Saving model with loss 0.977...
# Saving model with loss 0.926...
# Epoch 220 Train 1.13920 Valid 1.37112
# Epoch 225 Train 4.27982 Valid 4.03984
# Epoch 230 Train 3.17598 Valid 2.39709
# Epoch 235 Train 1.99898 Valid 1.69419
# Epoch 240 Train 1.22665 Valid 0.87005
# Saving model with loss 0.870...
# Epoch 245 Train 1.05919 Valid 1.02608
# Epoch 250 Train 5.47308 Valid 2.43275
# Epoch 255 Train 1.98131 Valid 1.61410
# Saving model with loss 0.805...
# Epoch 260 Train 5.57827 Valid 7.57106
# Epoch 265 Train 2.83805 Valid 2.73205
# Epoch 270 Train 2.25753 Valid 1.62403
# Saving model with loss 0.788...
# Epoch 275 Train 1.54755 Valid 1.47905
# Epoch 280 Train 2.65627 Valid 3.13801
# Epoch 285 Train 3.06515 Valid 3.48059
# Epoch 290 Train 3.88545 Valid 1.58313
# Epoch 295 Train 4.64775 Valid 1.53260
# Epoch 300 Train 1.23711 Valid 1.03342
# Epoch 305 Train 3.88846 Valid 6.41011
# Epoch 310 Train 1.97745 Valid 2.38878
# Epoch 315 Train 3.70556 Valid 1.85348
# Epoch 320 Train 1.27947 Valid 1.13925
# Epoch 325 Train 1.38517 Valid 1.15490
# Saving model with loss 0.647...
# Epoch 330 Train 4.30056 Valid 1.15659
# Epoch 335 Train 2.32937 Valid 10.05581
# Epoch 340 Train 4.00265 Valid 0.93908
# Epoch 345 Train 3.05371 Valid 2.76323
# Epoch 350 Train 2.22165 Valid 0.91600
# Epoch 355 Train 1.50920 Valid 1.32453
# Epoch 360 Train 4.37833 Valid 4.70063
# Epoch 365 Train 2.33750 Valid 1.83149
# Epoch 370 Train 0.94915 Valid 0.79351
# Epoch 375 Train 1.45616 Valid 1.31795
# Epoch 380 Train 1.19749 Valid 0.69506
# Epoch 385 Train 1.40648 Valid 1.81112
# Epoch 390 Train 0.85415 Valid 0.73615
# Epoch 395 Train 1.51013 Valid 1.78110
# Epoch 400 Train 14.79764 Valid 9.27796
# Epoch 405 Train 1.12899 Valid 0.87141
# Epoch 410 Train 0.73348 Valid 2.29529
# Epoch 415 Train 1.64360 Valid 1.54291
# Epoch 420 Train 1.40956 Valid 1.87192
# Saving model with loss 0.510...
# Epoch 425 Train 0.38101 Valid 0.54515
# Saving model with loss 0.472...
# Saving model with loss 0.466...
# Epoch 430 Train 0.36172 Valid 0.84453
# Saving model with loss 0.455...
# Saving model with loss 0.430...
# Epoch 435 Train 0.34765 Valid 0.45148
# Epoch 440 Train 0.33337 Valid 0.43734
# Epoch 445 Train 0.40208 Valid 0.43763
# Epoch 450 Train 0.32319 Valid 0.46610
# Epoch 455 Train 0.33550 Valid 0.41234
# Saving model with loss 0.412...
# Epoch 460 Train 0.36157 Valid 0.54660
# Epoch 465 Train 0.35128 Valid 0.48584
# Epoch 470 Train 0.38352 Valid 0.63535
# Epoch 475 Train 0.75555 Valid 0.50516
# Epoch 480 Train 0.36568 Valid 0.50010
# Epoch 485 Train 0.55055 Valid 0.82146
# Epoch 490 Train 0.51577 Valid 0.52877
# Epoch 495 Train 0.56852 Valid 0.65237
# Epoch 500 Train 0.90159 Valid 2.88911
# Epoch 505 Train 0.43114 Valid 0.54928
# Epoch 510 Train 0.47212 Valid 0.63730
# Epoch 515 Train 1.20396 Valid 0.98856
# Epoch 520 Train 0.53361 Valid 0.59667
# Epoch 525 Train 0.76183 Valid 0.76060
# Epoch 530 Train 0.39945 Valid 1.87126
# Epoch 535 Train 0.48424 Valid 0.73593
# Epoch 540 Train 0.85827 Valid 0.53542
# Epoch 545 Train 0.62554 Valid 0.53351
# Epoch 550 Train 0.47549 Valid 0.62317
# Epoch 555 Train 0.51994 Valid 0.74793
# Epoch 560 Train 0.41454 Valid 0.64599
# Epoch 565 Train 0.46694 Valid 0.61173
# Epoch 570 Train 0.53007 Valid 0.74849
# Epoch 575 Train 0.50287 Valid 0.51441
# Epoch 580 Train 0.70469 Valid 0.96924
# Epoch 585 Train 0.76139 Valid 1.87728
# Epoch 590 Train 0.48436 Valid 0.67400
# Epoch 595 Train 0.55704 Valid 0.45350
# Epoch 600 Train 0.99280 Valid 0.63361
# Epoch 605 Train 0.64818 Valid 0.68954
# Epoch 610 Train 1.43782 Valid 0.88829
# Epoch 615 Train 0.69296 Valid 0.55123
# Epoch 620 Train 0.75650 Valid 1.18581
# Epoch 625 Train 0.30787 Valid 0.48285
# Epoch 630 Train 0.44460 Valid 0.78782
# Epoch 635 Train 0.51024 Valid 0.58660
# Epoch 640 Train 0.52953 Valid 0.43676
# Epoch 645 Train 0.67086 Valid 0.62181
# Epoch 650 Train 0.32248 Valid 0.71766
# Epoch 655 Train 0.42841 Valid 0.55625
# Epoch 660 Train 0.61137 Valid 0.64421
# Epoch 665 Train 0.57842 Valid 0.42154
# Saving model with loss 0.401...
# Epoch 670 Train 0.43566 Valid 0.70333
# Epoch 675 Train 1.00661 Valid 0.98283
# Epoch 680 Train 0.51173 Valid 0.64617
# Epoch 685 Train 0.25741 Valid 0.50284
# Epoch 690 Train 0.51616 Valid 0.48567
# Epoch 695 Train 0.26253 Valid 0.49534
# Epoch 700 Train 0.37512 Valid 0.41549
# Epoch 705 Train 0.41217 Valid 0.44254
# Epoch 710 Train 0.46263 Valid 0.72518
# Epoch 715 Train 0.65579 Valid 0.58177
# Epoch 720 Train 0.37924 Valid 0.49036
# Saving model with loss 0.391...
# Epoch 725 Train 0.59768 Valid 0.49905
# Epoch 730 Train 0.50712 Valid 0.69705
# Epoch 735 Train 1.03669 Valid 1.00508
# Epoch 740 Train 0.38040 Valid 0.45194
# Epoch 745 Train 0.44799 Valid 0.59153
# Epoch 750 Train 0.43425 Valid 0.97980
# Epoch 755 Train 0.62620 Valid 1.29802
# Epoch 760 Train 0.57407 Valid 0.52268
# Epoch 765 Train 0.28332 Valid 0.46977
# Epoch 770 Train 0.33029 Valid 0.84439
# Epoch 775 Train 0.23870 Valid 0.45984
# Epoch 780 Train 0.66047 Valid 0.74836
# Saving model with loss 0.383...
# Epoch 785 Train 0.20140 Valid 0.42459
# Saving model with loss 0.378...
# Epoch 790 Train 0.29738 Valid 0.43658
# Epoch 795 Train 0.35160 Valid 1.02607
# Epoch 800 Train 0.62376 Valid 1.55349
# Epoch 805 Train 1.11429 Valid 1.31106
# Epoch 810 Train 0.33509 Valid 0.56653
# Epoch 815 Train 0.17910 Valid 0.35904
# Saving model with loss 0.359...
# Epoch 820 Train 1.06549 Valid 0.56547
# Epoch 825 Train 0.22013 Valid 0.36520
# Epoch 830 Train 0.29242 Valid 0.64206
# Saving model with loss 0.353...
# Epoch 835 Train 0.24283 Valid 0.39729
# Epoch 840 Train 0.33307 Valid 0.88704
# Epoch 845 Train 0.51514 Valid 0.64880
# Saving model with loss 0.342...
# Epoch 850 Train 0.13105 Valid 0.32468
# Saving model with loss 0.325...
# Saving model with loss 0.322...
# Epoch 855 Train 0.12125 Valid 0.34024
# Saving model with loss 0.319...
# Epoch 860 Train 0.11731 Valid 0.35214
# Saving model with loss 0.318...
# Epoch 865 Train 0.11940 Valid 0.35934
# Epoch 870 Train 0.12457 Valid 0.33627
# Epoch 875 Train 0.11325 Valid 0.34012
# Epoch 880 Train 0.14231 Valid 0.38920
# Epoch 885 Train 0.11276 Valid 0.33992
# Epoch 890 Train 0.12123 Valid 0.32704
# Epoch 895 Train 0.12551 Valid 0.33922
# Epoch 900 Train 0.22464 Valid 0.52304
# Epoch 905 Train 0.27388 Valid 0.39793
# Epoch 910 Train 0.22203 Valid 0.35599
# Epoch 915 Train 0.15294 Valid 0.36995
# Epoch 920 Train 0.16931 Valid 0.36789
# Saving model with loss 0.316...
# Epoch 925 Train 0.27390 Valid 0.53721
# Epoch 930 Train 0.13068 Valid 0.36723
# Epoch 935 Train 0.15040 Valid 0.66403
# Epoch 940 Train 0.19262 Valid 0.34510
# Epoch 945 Train 0.14247 Valid 0.37386
# Epoch 950 Train 0.11953 Valid 0.35322
# Epoch 955 Train 0.11691 Valid 0.33493
# Epoch 960 Train 0.20823 Valid 0.55915
# Epoch 965 Train 0.30871 Valid 0.67897
# Epoch 970 Train 0.13990 Valid 0.35163
# Epoch 975 Train 0.18318 Valid 0.34647
# Epoch 980 Train 0.11950 Valid 0.34832
# Epoch 985 Train 0.23580 Valid 0.39383
# Epoch 990 Train 0.15988 Valid 0.41780
# Epoch 995 Train 0.16066 Valid 0.36481
# Epoch 1000 Train 0.24284 Valid 0.47578
# Epoch 1005 Train 0.15865 Valid 0.37285
# Epoch 1010 Train 0.19398 Valid 0.54348
# Epoch 1015 Train 0.15681 Valid 0.38075
# Epoch 1020 Train 0.12275 Valid 0.34216
# Epoch 1025 Train 0.16795 Valid 0.36769
# Epoch 1030 Train 0.20677 Valid 0.37565
# Epoch 1035 Train 0.23224 Valid 0.39038
# Epoch 1040 Train 0.21658 Valid 0.53022
# Epoch 1045 Train 0.15411 Valid 0.34368
# Epoch 1050 Train 0.16852 Valid 0.67608
# Epoch 1055 Train 0.18521 Valid 0.37398
# Epoch 1060 Train 0.14099 Valid 0.55521
# Epoch 1065 Train 0.13832 Valid 0.38444
# Epoch 1070 Train 0.28097 Valid 0.37376
# Epoch 1075 Train 0.16265 Valid 0.36731
# Epoch 1080 Train 0.15394 Valid 0.37921
# Epoch 1085 Train 0.17138 Valid 0.37696
# Epoch 1090 Train 0.12719 Valid 0.32976
# Epoch 1095 Train 0.19283 Valid 0.43615
# Epoch 1100 Train 0.17511 Valid 0.39419
# Epoch 1105 Train 0.18245 Valid 0.36307
# Epoch 1110 Train 0.16151 Valid 0.43122
# Epoch 1115 Train 0.13424 Valid 0.36737
# Epoch 1120 Train 0.18515 Valid 0.46910
# Epoch 1125 Train 0.24139 Valid 0.57336
# Epoch 1130 Train 0.14284 Valid 0.45929
# Epoch 1135 Train 0.13654 Valid 0.41652
# Epoch 1140 Train 0.10346 Valid 0.37889
# Epoch 1145 Train 0.20000 Valid 0.37125
# Epoch 1150 Train 0.17721 Valid 0.38662
# Epoch 1155 Train 0.17305 Valid 0.41813
# Epoch 1160 Train 0.25216 Valid 0.51231
# Epoch 1165 Train 0.24043 Valid 0.45478
# Epoch 1170 Train 0.13644 Valid 0.36093
# Epoch 1175 Train 0.12667 Valid 0.38627
# Epoch 1180 Train 0.09738 Valid 0.32773
# Epoch 1185 Train 0.24283 Valid 0.48897
# Epoch 1190 Train 0.13552 Valid 0.72396
# Epoch 1195 Train 0.21572 Valid 0.44757
# Epoch 1200 Train 0.18222 Valid 0.41152
# Epoch 1205 Train 0.11381 Valid 0.49015
# Epoch 1210 Train 0.32096 Valid 0.90259
# Epoch 1215 Train 0.21137 Valid 0.48101
# Epoch 1220 Train 0.11839 Valid 0.40635
# Epoch 1225 Train 0.15208 Valid 0.53843
# Epoch 1230 Train 0.09407 Valid 0.37591
# Epoch 1235 Train 0.29242 Valid 0.66394
# Epoch 1240 Train 0.12247 Valid 0.34967
# Epoch 1245 Train 0.14528 Valid 0.33879
# Epoch 1250 Train 0.10671 Valid 0.37120
# Epoch 1255 Train 0.12859 Valid 0.39490
# Epoch 1260 Train 0.54397 Valid 0.63220
# Epoch 1265 Train 0.14846 Valid 0.35387
# Epoch 1270 Train 0.08316 Valid 0.33273
# Epoch 1275 Train 0.06494 Valid 0.32372
# Epoch 1280 Train 0.07304 Valid 0.33093
# Epoch 1285 Train 0.06544 Valid 0.33145
# Epoch 1290 Train 0.06855 Valid 0.32780
# Epoch 1295 Train 0.06616 Valid 0.33517
# Epoch 1300 Train 0.09485 Valid 0.36594
# Epoch 1305 Train 0.07758 Valid 0.33647
# Epoch 1310 Train 0.07327 Valid 0.34187
# Epoch 1315 Train 0.07296 Valid 0.34002
# Epoch 1320 Train 0.07865 Valid 0.37535
# Epoch 1325 Train 0.09429 Valid 0.35603
# Epoch 1330 Train 0.06925 Valid 0.32995
# Epoch 1335 Train 0.07799 Valid 0.33160
# Epoch 1340 Train 0.07532 Valid 0.35185
# Epoch 1345 Train 0.06819 Valid 0.34459
# Epoch 1350 Train 0.08950 Valid 0.32914
# Epoch 1355 Train 0.07617 Valid 0.34799
# Epoch 1360 Train 0.09031 Valid 0.33151
# Epoch 1365 Train 0.09144 Valid 0.40881
# Epoch 1370 Train 0.09780 Valid 0.33554
# Epoch 1375 Train 0.07136 Valid 0.35696
# Epoch 1380 Train 0.10667 Valid 0.36739
# Epoch 1385 Train 0.07041 Valid 0.33282
# Epoch 1390 Train 0.10774 Valid 0.42629
# Epoch 1395 Train 0.07807 Valid 0.39060
# Epoch 1400 Train 0.09166 Valid 0.34750
# Epoch 1405 Train 0.09253 Valid 0.39004
# Epoch 1410 Train 0.07393 Valid 0.37064
# Epoch 1415 Train 0.08471 Valid 0.38438
# Epoch 1420 Train 0.09932 Valid 0.36106
# Model is not improving, so we halt the training session.
# Training finished! Model is saved!
# Best model is load to test
# Test Loss: 0.04830
# yy_pred : (104, 1)
# yy_meas : (104, 1)
# Relative Error: 3.63904421
# AVG Error: 3.63904421
# 95-PRCT Error: 11.04889818
# 99th Percentile Error: 15.49924384
# MAX Error: 15.65485536
