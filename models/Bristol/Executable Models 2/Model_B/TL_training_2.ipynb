# %% [markdown]
# # User Colab Path Setting

# %%
colab_dir = '/content/drive/MyDrive/DeepLearning/Challange_comb_shift_flip/MagNet_comb_modelB_cycle'  # example for colab

platform = 'auto' # auto detect platform (colab, windows_local, linux_local, unknown)
#platform = 'colab'
#platform = 'windows_local'
#platform = 'linux_local'
#platform = 'unknown'

# %% [markdown]
# # Trainnig process

# %% [markdown]
# ### Defult path config

# %%
model_saved_name="model_tl.ckpt"
dataset_path="data/tl_dataset"

# %% [markdown]
# ### Path config

# %%
import os

try:
    from google.colab import drive
    drive.mount("/content/drive")
except ImportError:
    if os.path.exists('c:/'):  # check if it is windows
        platform = 'windows_local'
    elif os.path.exists('/home/'):  # check if it is linux
        platform = 'linux_local'
    else:
        platform = 'unknown'
else:
    platform = 'colab'

if platform == 'colab':
  os.chdir(colab_dir)

print('\ncurrent execution path: ', os.getcwd())  #获取当前工作目录路径
print('\ncurrent platform: ', platform)  #获取当前工作目录路径
# Out:
# Mounted at /content/drive
#
# current execution path:  /content/drive/MyDrive/DeepLearning/Challange_comb_shift_flip/MagNet_comb_modelB_cycle
#
# current platform:  colab

# %% [markdown]
# ## Cuda check

# %%
import torch

gpu_num = 0
cuda_ready = False

if torch.cuda.is_available():
    cuda_ready = True
    print('cuda good!')
    gpu_num = torch.cuda.device_count()
    if (gpu_num < 1):
        print('GPU unavailable')
    else:
        print('GPU num: ', gpu_num)  # 查看GPU数量
        for gpu in range(gpu_num):
            print('GPU type: ', torch.cuda.get_device_name(gpu))  # 查看GPU名称
            print('GPU memory: {:.2f} Gbyte'.format(
                torch.cuda.get_device_properties(gpu).total_memory /
                1e9))  # 查看GPU总内存
else:
    cuda_ready = False
    print('cuda unavailable!')
# Out:
# cuda good!
# GPU num:  1
# GPU type:  NVIDIA A100-SXM4-40GB
# GPU memory: 42.48 Gbyte

# %% [markdown]
# ## Start coding

# %%
print(platform)
print(os.getcwd())
print(cuda_ready)
print(os.path.abspath(''))
# Out:
# colab
# /content/drive/MyDrive/DeepLearning/Challange_comb_shift_flip/MagNet_comb_modelB_cycle
# True
# /content/drive/MyDrive/DeepLearning/Challange_comb_shift_flip/MagNet_comb_modelB_cycle

# %%
import numpy as np
import torch
import torch.optim as optim
import torch.nn as nn
import matplotlib.pyplot as plt


import NW_LSTM
import NN_DataLoader

# %%
# Check if CUDA is available and if so, set the device to GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#device = torch.device("cpu")
print("Device using ",device)

# Instantiate the model with appropriate dimensions
model = model = NW_LSTM.get_global_model().to(device)

# Print the model architecture and parameters number
print(model)
print("Total number of parameters: ", sum(p.numel() for p in model.parameters()))

# Load the pre-train model if it exists
try:
    model.load_state_dict(torch.load(model_saved_name))
    print("Pre-train model loaded")
except:
    print("No model found, start training from scratch")
    pass
# Out:
# Device using  cuda
# LSTMSeq2One(
#   (lstm): LSTM(1, 30, num_layers=3, batch_first=True)
#   (fc1): Linear(in_features=32, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=196, bias=True)
#   (fc3): Linear(in_features=196, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=96, bias=True)
#   (fc5): Linear(in_features=96, out_features=32, bias=True)
#   (fc6): Linear(in_features=32, out_features=32, bias=True)
#   (fc7): Linear(in_features=32, out_features=16, bias=True)
#   (fc8): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
#   (leaky_relu): LeakyReLU(negative_slope=0.01)
#   (elu): ELU(alpha=1.0)
#   (sigmoid): Sigmoid()
# )
# Total number of parameters:  90653
# Pre-train model loaded

# %% [markdown]
# ### Define training para

# %%
def train_model(epoch_num=700,lr=2e-4,method="forward"):

    # Define the loss function and optimizer
    #loss_fn = nn.MSELoss()
    loss_fn = NW_LSTM.RelativeLoss()
    #loss_fn = NW_LSTM.RelativeLoss_abs()
    optimizer = optim.AdamW(model.parameters(), lr=lr)

    # lr scheduler
    #scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=1, last_epoch=-1)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200, eta_min=0, last_epoch=-1)

    # Default para in desktop env
    epochs = 10
    valid_batch_size=1000

    if platform == "colab":
      epochs = epoch_num
      valid_batch_size=3000


    train_dataloader = NN_DataLoader.get_dataLoader(os.path.normpath(dataset_path +
                                                                "/train.mat"),
                                            batch_size=128)

    # Get validation data
    valid_dataloader = NN_DataLoader.get_dataLoader(os.path.normpath(dataset_path +
                                                                "/valid.mat"),
                                                batch_size=valid_batch_size)
    valid_inputs, valid_targets = next(iter(valid_dataloader))
    valid_inputs, valid_targets = valid_inputs.to(device), valid_targets.to(device)



    # estimate time used for training
    import time
    t0 = time.perf_counter()

    # Save the model with the lowest validation loss
    with torch.no_grad():
        valid_outputs = model(valid_inputs)
        # Compute loss
        minium_loss = loss_fn(valid_outputs, valid_targets)

    # Train the model
    for epoch in range(epochs):


        # estimate time used for one epoch(s)
        t_epoch = time.perf_counter() - t0
        t0 = time.perf_counter()

        # Train one epoch
        for i, (train_inputs, train_targets) in enumerate(train_dataloader):
            # Move data to device
            train_inputs, train_targets = train_inputs.to(device), train_targets.to(device)

            # Forward pass
            if method == "forward":
                train_outputs = model(train_inputs)
            elif method == "valid":
                train_outputs = model.valid(train_inputs)

            # Compute loss
            loss = loss_fn(train_outputs, train_targets)

            # Backward pass and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        # Compute validation loss
        if epoch > 0:
            with torch.no_grad():
                valid_outputs = model(valid_inputs)
                # Compute loss
                valid_loss = loss_fn(valid_outputs, valid_targets)

            if valid_loss < minium_loss:
                minium_loss = valid_loss
                torch.save(model.state_dict(), model_saved_name)
                print(f"  Model saved , Validation Loss: {valid_loss.item():.3e}, lr: {optimizer.param_groups[0]['lr']:.3e}")

        # update lr
        scheduler.step()

        # Print loss every 10 epochs
        if (epoch + 1) % 10 == 0:
            print(f"Epoch {epoch + 1}/{epochs}, Training Loss: {loss.item():.3e}, "
                #   f"Validation Loss: {valid_loss.item():.3e} ,"
                f"Remain time: {t_epoch/60 * (epochs - epoch - 1):.1f} min")

# %% [markdown]
# ### Training loop

# %%
#train_model(epoch_num=10,lr=2e-4,method="forward")

# %%
#train_model(epoch_num=300,lr=2e-4,method="forward")
train_model(epoch_num=700,lr=2e-5,method="forward")
# Out:
#   Model saved , Validation Loss: 2.152e-04, lr: 1.999e-05
# Epoch 10/700, Training Loss: 1.055e-04, Remain time: 12.2 min
# Epoch 20/700, Training Loss: 1.620e-04, Remain time: 12.1 min
#   Model saved , Validation Loss: 2.083e-04, lr: 1.951e-05
# Epoch 30/700, Training Loss: 7.687e-05, Remain time: 11.9 min
# Epoch 40/700, Training Loss: 5.768e-04, Remain time: 11.6 min
# Epoch 50/700, Training Loss: 1.133e-04, Remain time: 11.4 min
# Epoch 60/700, Training Loss: 1.219e-04, Remain time: 11.4 min
# Epoch 70/700, Training Loss: 8.388e-05, Remain time: 11.0 min
# Epoch 80/700, Training Loss: 9.630e-05, Remain time: 11.0 min
# Epoch 90/700, Training Loss: 1.027e-04, Remain time: 10.7 min
# Epoch 100/700, Training Loss: 2.528e-04, Remain time: 10.6 min
# Epoch 110/700, Training Loss: 8.316e-05, Remain time: 10.5 min
# Epoch 120/700, Training Loss: 7.360e-05, Remain time: 10.3 min
#   Model saved , Validation Loss: 2.066e-04, lr: 5.601e-06
# Epoch 130/700, Training Loss: 8.041e-05, Remain time: 9.9 min
# Epoch 140/700, Training Loss: 1.023e-04, Remain time: 9.8 min
#   Model saved , Validation Loss: 2.050e-04, lr: 3.871e-06
#   Model saved , Validation Loss: 2.047e-04, lr: 3.387e-06
# Epoch 150/700, Training Loss: 1.077e-04, Remain time: 9.6 min
# Epoch 160/700, Training Loss: 3.187e-04, Remain time: 9.9 min
# Epoch 170/700, Training Loss: 1.579e-04, Remain time: 9.3 min
#   Model saved , Validation Loss: 2.032e-04, lr: 7.022e-07
# Epoch 180/700, Training Loss: 1.379e-04, Remain time: 9.4 min
#   Model saved , Validation Loss: 2.031e-04, lr: 4.894e-07
#   Model saved , Validation Loss: 2.020e-04, lr: 1.489e-07
# Epoch 190/700, Training Loss: 1.470e-04, Remain time: 9.2 min
# Epoch 200/700, Training Loss: 2.043e-04, Remain time: 8.8 min
# Epoch 210/700, Training Loss: 1.571e-04, Remain time: 8.6 min
# Epoch 220/700, Training Loss: 1.484e-04, Remain time: 8.5 min
# Epoch 230/700, Training Loss: 1.115e-04, Remain time: 8.3 min
# Epoch 240/700, Training Loss: 5.196e-05, Remain time: 8.1 min
# Epoch 250/700, Training Loss: 1.489e-04, Remain time: 8.0 min
# Epoch 260/700, Training Loss: 1.191e-04, Remain time: 7.6 min
# Epoch 270/700, Training Loss: 1.671e-04, Remain time: 7.6 min
# Epoch 280/700, Training Loss: 1.745e-04, Remain time: 7.4 min
# Epoch 290/700, Training Loss: 1.043e-04, Remain time: 7.2 min
# Epoch 300/700, Training Loss: 2.079e-04, Remain time: 7.0 min
# Epoch 310/700, Training Loss: 1.046e-04, Remain time: 7.0 min
# Epoch 320/700, Training Loss: 8.722e-05, Remain time: 6.7 min
# Epoch 330/700, Training Loss: 1.562e-04, Remain time: 6.5 min
# Epoch 340/700, Training Loss: 2.442e-04, Remain time: 6.4 min
# Epoch 350/700, Training Loss: 2.395e-04, Remain time: 6.2 min
# Epoch 360/700, Training Loss: 1.040e-04, Remain time: 6.0 min
# Epoch 370/700, Training Loss: 8.773e-05, Remain time: 5.8 min
# Epoch 380/700, Training Loss: 2.327e-04, Remain time: 5.6 min
# Epoch 390/700, Training Loss: 6.594e-05, Remain time: 5.4 min
# Epoch 400/700, Training Loss: 1.229e-04, Remain time: 5.3 min
# Epoch 410/700, Training Loss: 1.089e-04, Remain time: 5.1 min
# Epoch 420/700, Training Loss: 1.881e-04, Remain time: 5.1 min
# Epoch 430/700, Training Loss: 5.179e-05, Remain time: 4.8 min
# Epoch 440/700, Training Loss: 9.200e-05, Remain time: 4.6 min
# Epoch 450/700, Training Loss: 2.284e-04, Remain time: 4.4 min
# Epoch 460/700, Training Loss: 1.369e-04, Remain time: 4.2 min
# Epoch 470/700, Training Loss: 7.244e-05, Remain time: 4.0 min
# Epoch 480/700, Training Loss: 2.575e-04, Remain time: 3.9 min
#   Model saved , Validation Loss: 1.964e-04, lr: 1.279e-05
# Epoch 490/700, Training Loss: 5.393e-05, Remain time: 3.8 min
# Epoch 500/700, Training Loss: 1.561e-04, Remain time: 3.5 min
# Epoch 510/700, Training Loss: 1.641e-04, Remain time: 3.4 min
# Epoch 520/700, Training Loss: 8.472e-05, Remain time: 3.2 min
# Epoch 530/700, Training Loss: 9.336e-05, Remain time: 3.0 min
# Epoch 540/700, Training Loss: 2.410e-04, Remain time: 2.8 min
# Epoch 550/700, Training Loss: 1.282e-04, Remain time: 2.7 min
# Epoch 560/700, Training Loss: 1.281e-04, Remain time: 2.5 min
# Epoch 570/700, Training Loss: 1.106e-04, Remain time: 2.3 min
# Epoch 580/700, Training Loss: 1.881e-04, Remain time: 2.1 min
# Epoch 590/700, Training Loss: 8.110e-05, Remain time: 2.0 min
# Epoch 600/700, Training Loss: 2.654e-04, Remain time: 1.8 min
# Epoch 610/700, Training Loss: 1.727e-04, Remain time: 1.6 min
# Epoch 620/700, Training Loss: 1.008e-04, Remain time: 1.4 min
# Epoch 630/700, Training Loss: 8.492e-05, Remain time: 1.2 min
# Epoch 640/700, Training Loss: 8.414e-05, Remain time: 1.0 min
# Epoch 650/700, Training Loss: 1.452e-04, Remain time: 0.9 min
# Epoch 660/700, Training Loss: 6.523e-05, Remain time: 0.7 min
#   Model saved , Validation Loss: 1.889e-04, lr: 5.182e-06
# Epoch 670/700, Training Loss: 1.201e-04, Remain time: 0.5 min
# Epoch 680/700, Training Loss: 8.019e-05, Remain time: 0.4 min
# Epoch 690/700, Training Loss: 1.220e-04, Remain time: 0.2 min
# Epoch 700/700, Training Loss: 2.505e-04, Remain time: 0.0 min

# %% [markdown]
# ## GPU monitor
# ### nvidia-smi -l 3
