# %% [markdown]
# # User Colab Path Setting

# %%
colab_dir = '/content/drive/MyDrive/DeepLearning/Challange_comb_shift_flip/MagNet_comb_modelB_cycle_dataClean'  # example for colab

platform = 'auto' # auto detect platform (colab, windows_local, linux_local, unknown)
#platform = 'colab'
#platform = 'windows_local'
#platform = 'linux_local'
#platform = 'unknown'

# %% [markdown]
# # Trainnig process

# %% [markdown]
# ### Defult path config

# %%
model_saved_name="model_tl.ckpt"
dataset_path="data/tl_dataset"

# %% [markdown]
# ### Path config

# %%
import os

try:
    from google.colab import drive
    drive.mount("/content/drive")
except ImportError:
    if os.path.exists('c:/'):  # check if it is windows
        platform = 'windows_local'
    elif os.path.exists('/home/'):  # check if it is linux
        platform = 'linux_local'
    else:
        platform = 'unknown'
else:
    platform = 'colab'

if platform == 'colab':
  os.chdir(colab_dir)

print('\ncurrent execution path: ', os.getcwd())  #获取当前工作目录路径
print('\ncurrent platform: ', platform)  #获取当前工作目录路径
# Out:
# Mounted at /content/drive
#
# current execution path:  /content/drive/MyDrive/DeepLearning/MagNet_Final_test_comb/MagNet_comb_modelB_cycle_dataClean
#
# current platform:  colab

# %% [markdown]
# ## Cuda check

# %%
import torch

gpu_num = 0
cuda_ready = False

if torch.cuda.is_available():
    cuda_ready = True
    print('cuda good!')
    gpu_num = torch.cuda.device_count()
    if (gpu_num < 1):
        print('GPU unavailable')
    else:
        print('GPU num: ', gpu_num)  # 查看GPU数量
        for gpu in range(gpu_num):
            print('GPU type: ', torch.cuda.get_device_name(gpu))  # 查看GPU名称
            print('GPU memory: {:.2f} Gbyte'.format(
                torch.cuda.get_device_properties(gpu).total_memory /
                1e9))  # 查看GPU总内存
else:
    cuda_ready = False
    print('cuda unavailable!')
# Out:
# cuda good!
# GPU num:  1
# GPU type:  NVIDIA A100-SXM4-40GB
# GPU memory: 42.48 Gbyte

# %% [markdown]
# ## Start coding

# %%
print(platform)
print(os.getcwd())
print(cuda_ready)
print(os.path.abspath(''))
# Out:
# colab
# /content/drive/MyDrive/DeepLearning/MagNet_Final_test_comb/MagNet_comb_modelB_cycle_dataClean
# True
# /content/drive/MyDrive/DeepLearning/MagNet_Final_test_comb/MagNet_comb_modelB_cycle_dataClean

# %%
import numpy as np
import torch
import torch.optim as optim
import torch.nn as nn
import matplotlib.pyplot as plt


import NW_LSTM
import NN_DataLoader

# %%
# Check if CUDA is available and if so, set the device to GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#device = torch.device("cpu")
print("Device using ",device)

# Instantiate the model with appropriate dimensions
model = model = NW_LSTM.get_global_model().to(device)

# Print the model architecture and parameters number
print(model)
print("Total number of parameters: ", sum(p.numel() for p in model.parameters()))

# Load the pre-train model if it exists
try:
    model.load_state_dict(torch.load(model_saved_name))
    print("Pre-train model loaded")
except:
    print("No model found, start training from scratch")
    pass
# Out:
# Device using  cuda
# LSTMSeq2One(
#   (lstm): LSTM(1, 30, num_layers=3, batch_first=True)
#   (fc1): Linear(in_features=32, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=196, bias=True)
#   (fc3): Linear(in_features=196, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=96, bias=True)
#   (fc5): Linear(in_features=96, out_features=32, bias=True)
#   (fc6): Linear(in_features=32, out_features=32, bias=True)
#   (fc7): Linear(in_features=32, out_features=16, bias=True)
#   (fc8): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
#   (leaky_relu): LeakyReLU(negative_slope=0.01)
#   (elu): ELU(alpha=1.0)
#   (sigmoid): Sigmoid()
# )
# Total number of parameters:  90653
# Pre-train model loaded

# %% [markdown]
# ### Define training para

# %%
# Define the loss function and optimizer
#loss_fn = nn.MSELoss()
loss_fn = NW_LSTM.RelativeLoss()
#loss_fn = NW_LSTM.RelativeLoss_abs()
optimizer = optim.AdamW(model.parameters(), lr=2e-4)

# lr scheduler
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=1, last_epoch=-1)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200, eta_min=0, last_epoch=-1)

# %% [markdown]
# ### Training loop

# %%
# Default para in desktop env
epochs = 10
valid_batch_size=1000

if platform == "colab":
  epochs = 1500
  valid_batch_size=3000


train_dataloader = NN_DataLoader.get_dataLoader(os.path.normpath(dataset_path +
                                                            "/train.mat"),
                                          batch_size=128)

# Get validation data
valid_dataloader = NN_DataLoader.get_dataLoader(os.path.normpath(dataset_path +
                                                            "/valid.mat"),
                                            batch_size=valid_batch_size)
valid_inputs, valid_targets = next(iter(valid_dataloader))
valid_inputs, valid_targets = valid_inputs.to(device), valid_targets.to(device)



# estimate time used for training
import time
t0 = time.perf_counter()

# Save the model with the lowest validation loss
with torch.no_grad():
    valid_outputs = model(valid_inputs)
    # Compute loss
    minium_loss = loss_fn(valid_outputs, valid_targets)

# Train the model
for epoch in range(epochs):


    # estimate time used for one epoch(s)
    t_epoch = time.perf_counter() - t0
    t0 = time.perf_counter()

    # Train one epoch
    for i, (train_inputs, train_targets) in enumerate(train_dataloader):
        # Move data to device
        train_inputs, train_targets = train_inputs.to(device), train_targets.to(device)

        # Forward pass
        train_outputs = model(train_inputs)

        # Compute loss
        loss = loss_fn(train_outputs, train_targets)

        # Backward pass and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Compute validation loss
    if epoch > 0:
        with torch.no_grad():
            valid_outputs = model(valid_inputs)
            # Compute loss
            valid_loss = loss_fn(valid_outputs, valid_targets)

        if valid_loss < minium_loss:
            minium_loss = valid_loss
            torch.save(model.state_dict(), model_saved_name)
            print(f"  Model saved , Validation Loss: {valid_loss.item():.3e}, lr: {optimizer.param_groups[0]['lr']:.3e}")

    # update lr
    scheduler.step()

    # Print loss every 10 epochs
    if (epoch + 1) % 10 == 0:
        print(f"Epoch {epoch + 1}/{epochs}, Training Loss: {loss.item():.3e}, "
            #   f"Validation Loss: {valid_loss.item():.3e} ,"
              f"Remain time: {t_epoch/60 * (epochs - epoch - 1):.1f} min")
# Out:
#   Model saved , Validation Loss: 5.886e-03, lr: 2.000e-04
#   Model saved , Validation Loss: 3.331e-03, lr: 2.000e-04
#   Model saved , Validation Loss: 3.038e-03, lr: 1.999e-04
#   Model saved , Validation Loss: 2.414e-03, lr: 1.998e-04
#   Model saved , Validation Loss: 1.936e-03, lr: 1.997e-04
#   Model saved , Validation Loss: 1.876e-03, lr: 1.996e-04
# Epoch 10/1500, Training Loss: 2.073e-03, Remain time: 13.0 min
#   Model saved , Validation Loss: 1.757e-03, lr: 1.988e-04
#   Model saved , Validation Loss: 1.244e-03, lr: 1.969e-04
# Epoch 20/1500, Training Loss: 7.850e-04, Remain time: 13.5 min
#   Model saved , Validation Loss: 1.090e-03, lr: 1.941e-04
#   Model saved , Validation Loss: 9.721e-04, lr: 1.935e-04
#   Model saved , Validation Loss: 9.389e-04, lr: 1.930e-04
#   Model saved , Validation Loss: 8.019e-04, lr: 1.924e-04
#   Model saved , Validation Loss: 7.883e-04, lr: 1.911e-04
#   Model saved , Validation Loss: 7.581e-04, lr: 1.898e-04
# Epoch 30/1500, Training Loss: 5.417e-04, Remain time: 12.9 min
#   Model saved , Validation Loss: 7.140e-04, lr: 1.836e-04
# Epoch 40/1500, Training Loss: 8.057e-03, Remain time: 12.6 min
#   Model saved , Validation Loss: 6.802e-04, lr: 1.760e-04
#   Model saved , Validation Loss: 6.084e-04, lr: 1.729e-04
# Epoch 50/1500, Training Loss: 2.237e-04, Remain time: 12.7 min
#   Model saved , Validation Loss: 5.658e-04, lr: 1.696e-04
# Epoch 60/1500, Training Loss: 1.701e-02, Remain time: 12.4 min
#   Model saved , Validation Loss: 5.142e-04, lr: 1.468e-04
# Epoch 70/1500, Training Loss: 2.778e-04, Remain time: 12.4 min
#   Model saved , Validation Loss: 4.650e-04, lr: 1.383e-04
# Epoch 80/1500, Training Loss: 3.218e-04, Remain time: 12.5 min
#   Model saved , Validation Loss: 4.604e-04, lr: 1.187e-04
# Epoch 90/1500, Training Loss: 7.758e-04, Remain time: 12.4 min
#   Model saved , Validation Loss: 4.379e-04, lr: 1.094e-04
# Epoch 100/1500, Training Loss: 5.028e-04, Remain time: 12.3 min
# Epoch 110/1500, Training Loss: 2.002e-04, Remain time: 12.4 min
#   Model saved , Validation Loss: 4.371e-04, lr: 8.126e-05
# Epoch 120/1500, Training Loss: 6.235e-04, Remain time: 12.3 min
#   Model saved , Validation Loss: 4.007e-04, lr: 6.613e-05
#   Model saved , Validation Loss: 3.843e-04, lr: 6.319e-05
#   Model saved , Validation Loss: 3.676e-04, lr: 6.029e-05
# Epoch 130/1500, Training Loss: 3.612e-04, Remain time: 12.2 min
#   Model saved , Validation Loss: 3.635e-04, lr: 5.182e-05
#   Model saved , Validation Loss: 3.440e-04, lr: 4.379e-05
# Epoch 140/1500, Training Loss: 3.210e-04, Remain time: 11.9 min
#   Model saved , Validation Loss: 3.409e-04, lr: 3.996e-05
#   Model saved , Validation Loss: 3.188e-04, lr: 3.155e-05
# Epoch 150/1500, Training Loss: 3.688e-04, Remain time: 12.1 min
# Epoch 160/1500, Training Loss: 1.340e-04, Remain time: 11.7 min
# Epoch 170/1500, Training Loss: 2.556e-04, Remain time: 11.7 min
# Epoch 180/1500, Training Loss: 2.715e-04, Remain time: 11.2 min
# Epoch 190/1500, Training Loss: 1.672e-04, Remain time: 11.4 min
# Epoch 200/1500, Training Loss: 2.886e-04, Remain time: 11.7 min
# Epoch 210/1500, Training Loss: 3.095e-04, Remain time: 11.2 min
# Epoch 220/1500, Training Loss: 2.483e-04, Remain time: 11.1 min
#   Model saved , Validation Loss: 3.152e-04, lr: 6.456e-06
#   Model saved , Validation Loss: 3.102e-04, lr: 8.860e-06
# Epoch 230/1500, Training Loss: 1.900e-04, Remain time: 11.0 min
#   Model saved , Validation Loss: 3.088e-04, lr: 1.090e-05
# Epoch 240/1500, Training Loss: 2.309e-04, Remain time: 10.8 min
# Epoch 250/1500, Training Loss: 3.280e-04, Remain time: 11.1 min
# Epoch 260/1500, Training Loss: 7.080e-04, Remain time: 10.6 min
# Epoch 270/1500, Training Loss: 7.041e-04, Remain time: 11.0 min
# Epoch 280/1500, Training Loss: 1.411e-03, Remain time: 10.8 min
# Epoch 290/1500, Training Loss: 1.067e-03, Remain time: 10.6 min
# Epoch 300/1500, Training Loss: 2.024e-04, Remain time: 10.4 min
# Epoch 310/1500, Training Loss: 3.017e-04, Remain time: 10.3 min
# Epoch 320/1500, Training Loss: 6.153e-04, Remain time: 10.3 min
#   Model saved , Validation Loss: 2.782e-04, lr: 1.426e-04
# Epoch 330/1500, Training Loss: 1.532e-04, Remain time: 10.1 min
# Epoch 340/1500, Training Loss: 1.288e-03, Remain time: 10.4 min
# Epoch 350/1500, Training Loss: 3.889e-04, Remain time: 10.1 min
# Epoch 360/1500, Training Loss: 2.317e-04, Remain time: 10.0 min
# Epoch 370/1500, Training Loss: 2.142e-03, Remain time: 9.8 min
# Epoch 380/1500, Training Loss: 3.112e-03, Remain time: 9.6 min
# Epoch 390/1500, Training Loss: 3.214e-04, Remain time: 9.5 min
# Epoch 400/1500, Training Loss: 7.816e-04, Remain time: 9.4 min
# Epoch 410/1500, Training Loss: 3.136e-04, Remain time: 9.3 min
# Epoch 420/1500, Training Loss: 2.744e-04, Remain time: 9.3 min
# Epoch 430/1500, Training Loss: 4.401e-04, Remain time: 9.6 min
# Epoch 440/1500, Training Loss: 3.104e-04, Remain time: 9.4 min
# Epoch 450/1500, Training Loss: 2.615e-03, Remain time: 9.0 min
# Epoch 460/1500, Training Loss: 2.957e-04, Remain time: 9.1 min
# Epoch 470/1500, Training Loss: 1.525e-03, Remain time: 8.9 min
# Epoch 480/1500, Training Loss: 5.615e-04, Remain time: 8.6 min
# Epoch 490/1500, Training Loss: 3.163e-04, Remain time: 8.7 min
# Epoch 500/1500, Training Loss: 1.268e-04, Remain time: 8.8 min
#   Model saved , Validation Loss: 2.731e-04, lr: 9.529e-05
#   Model saved , Validation Loss: 2.661e-04, lr: 8.591e-05
# Epoch 510/1500, Training Loss: 2.797e-04, Remain time: 8.7 min
#   Model saved , Validation Loss: 2.637e-04, lr: 7.666e-05
# Epoch 520/1500, Training Loss: 1.904e-04, Remain time: 8.5 min
#   Model saved , Validation Loss: 2.553e-04, lr: 5.601e-05
# Epoch 530/1500, Training Loss: 1.085e-04, Remain time: 8.6 min
#   Model saved , Validation Loss: 2.468e-04, lr: 5.182e-05
# Epoch 540/1500, Training Loss: 1.943e-04, Remain time: 8.4 min
# Epoch 550/1500, Training Loss: 3.016e-04, Remain time: 8.3 min
#   Model saved , Validation Loss: 2.459e-04, lr: 2.929e-05
# Epoch 560/1500, Training Loss: 2.267e-04, Remain time: 8.0 min
#   Model saved , Validation Loss: 2.302e-04, lr: 1.819e-05
# Epoch 570/1500, Training Loss: 2.572e-04, Remain time: 8.6 min
# Epoch 580/1500, Training Loss: 1.494e-04, Remain time: 8.2 min
#   Model saved , Validation Loss: 2.271e-04, lr: 2.078e-06
# Epoch 590/1500, Training Loss: 1.629e-04, Remain time: 8.1 min
#   Model saved , Validation Loss: 2.169e-04, lr: 1.110e-07
# Epoch 600/1500, Training Loss: 2.067e-04, Remain time: 7.9 min
# Epoch 610/1500, Training Loss: 2.068e-04, Remain time: 7.8 min
# Epoch 620/1500, Training Loss: 2.111e-04, Remain time: 7.6 min
# Epoch 630/1500, Training Loss: 3.110e-04, Remain time: 7.5 min
# Epoch 640/1500, Training Loss: 1.487e-04, Remain time: 7.4 min
# Epoch 650/1500, Training Loss: 2.124e-04, Remain time: 7.5 min
# Epoch 660/1500, Training Loss: 8.098e-04, Remain time: 7.3 min
# Epoch 670/1500, Training Loss: 2.392e-04, Remain time: 7.2 min
# Epoch 680/1500, Training Loss: 1.557e-04, Remain time: 7.4 min
# Epoch 690/1500, Training Loss: 1.802e-04, Remain time: 7.1 min
# Epoch 700/1500, Training Loss: 8.880e-03, Remain time: 7.0 min
# Epoch 710/1500, Training Loss: 3.869e-04, Remain time: 6.8 min
# Epoch 720/1500, Training Loss: 1.943e-04, Remain time: 6.9 min
# Epoch 730/1500, Training Loss: 9.356e-04, Remain time: 6.9 min
# Epoch 740/1500, Training Loss: 1.867e-03, Remain time: 6.7 min
# Epoch 750/1500, Training Loss: 2.494e-04, Remain time: 6.5 min
# Epoch 760/1500, Training Loss: 3.275e-03, Remain time: 6.5 min
# Epoch 770/1500, Training Loss: 1.189e-03, Remain time: 6.5 min
# Epoch 780/1500, Training Loss: 1.720e-04, Remain time: 6.2 min
# Epoch 790/1500, Training Loss: 3.431e-04, Remain time: 6.1 min
# Epoch 800/1500, Training Loss: 3.804e-04, Remain time: 6.5 min
# Epoch 810/1500, Training Loss: 9.210e-04, Remain time: 6.0 min
# Epoch 820/1500, Training Loss: 9.037e-04, Remain time: 6.0 min
# Epoch 830/1500, Training Loss: 1.864e-03, Remain time: 6.0 min
# Epoch 840/1500, Training Loss: 7.775e-04, Remain time: 5.8 min
# Epoch 850/1500, Training Loss: 5.406e-03, Remain time: 5.6 min
# Epoch 860/1500, Training Loss: 2.247e-04, Remain time: 5.5 min
# Epoch 870/1500, Training Loss: 1.767e-04, Remain time: 5.5 min
# Epoch 880/1500, Training Loss: 5.268e-04, Remain time: 5.3 min
# Epoch 890/1500, Training Loss: 1.882e-04, Remain time: 5.3 min
# Epoch 900/1500, Training Loss: 1.721e-04, Remain time: 5.3 min
# Epoch 910/1500, Training Loss: 2.221e-04, Remain time: 5.1 min
# Epoch 920/1500, Training Loss: 2.046e-04, Remain time: 5.0 min
# Epoch 930/1500, Training Loss: 9.841e-04, Remain time: 5.0 min
# Epoch 940/1500, Training Loss: 1.534e-04, Remain time: 4.7 min
# Epoch 950/1500, Training Loss: 2.387e-04, Remain time: 4.7 min
# Epoch 960/1500, Training Loss: 1.439e-04, Remain time: 4.6 min
# Epoch 970/1500, Training Loss: 4.854e-05, Remain time: 4.6 min
# Epoch 980/1500, Training Loss: 1.355e-04, Remain time: 4.5 min
#   Model saved , Validation Loss: 2.109e-04, lr: 3.544e-06
# Epoch 990/1500, Training Loss: 2.529e-04, Remain time: 4.4 min
# Epoch 1000/1500, Training Loss: 1.780e-04, Remain time: 4.5 min
#   Model saved , Validation Loss: 2.043e-04, lr: 1.110e-07
# Epoch 1010/1500, Training Loss: 1.398e-04, Remain time: 4.3 min
# Epoch 1020/1500, Training Loss: 1.781e-04, Remain time: 4.0 min
# Epoch 1030/1500, Training Loss: 1.181e-04, Remain time: 4.3 min
# Epoch 1040/1500, Training Loss: 1.743e-04, Remain time: 4.0 min
# Epoch 1050/1500, Training Loss: 2.066e-04, Remain time: 3.9 min
# Epoch 1060/1500, Training Loss: 2.624e-04, Remain time: 3.9 min
# Epoch 1070/1500, Training Loss: 1.049e-04, Remain time: 3.7 min
# Epoch 1080/1500, Training Loss: 1.552e-04, Remain time: 3.8 min
# Epoch 1090/1500, Training Loss: 1.275e-03, Remain time: 3.6 min
# Epoch 1100/1500, Training Loss: 1.207e-04, Remain time: 3.4 min
# Epoch 1110/1500, Training Loss: 3.402e-04, Remain time: 3.5 min
# Epoch 1120/1500, Training Loss: 7.718e-04, Remain time: 3.3 min
# Epoch 1130/1500, Training Loss: 7.166e-04, Remain time: 3.2 min
# Epoch 1140/1500, Training Loss: 2.644e-04, Remain time: 3.1 min
# Epoch 1150/1500, Training Loss: 2.264e-04, Remain time: 3.0 min
# Epoch 1160/1500, Training Loss: 4.770e-04, Remain time: 3.0 min
# Epoch 1170/1500, Training Loss: 9.968e-04, Remain time: 2.8 min
# Epoch 1180/1500, Training Loss: 4.554e-04, Remain time: 2.8 min
# Epoch 1190/1500, Training Loss: 2.061e-04, Remain time: 2.7 min
# Epoch 1200/1500, Training Loss: 1.460e-04, Remain time: 2.6 min
# Epoch 1210/1500, Training Loss: 2.808e-04, Remain time: 2.5 min
# Epoch 1220/1500, Training Loss: 7.188e-04, Remain time: 2.4 min
# Epoch 1230/1500, Training Loss: 5.060e-03, Remain time: 2.3 min
# Epoch 1240/1500, Training Loss: 2.327e-04, Remain time: 2.2 min
# Epoch 1250/1500, Training Loss: 5.681e-04, Remain time: 2.1 min
# Epoch 1260/1500, Training Loss: 4.785e-04, Remain time: 2.1 min
# Epoch 1270/1500, Training Loss: 1.555e-04, Remain time: 2.0 min
# Epoch 1280/1500, Training Loss: 4.086e-04, Remain time: 1.9 min
# Epoch 1290/1500, Training Loss: 1.808e-04, Remain time: 1.9 min
# Epoch 1300/1500, Training Loss: 2.050e-04, Remain time: 1.7 min
# Epoch 1310/1500, Training Loss: 2.366e-04, Remain time: 1.7 min
# Epoch 1320/1500, Training Loss: 1.313e-04, Remain time: 1.6 min
# Epoch 1330/1500, Training Loss: 3.958e-04, Remain time: 1.4 min
# Epoch 1340/1500, Training Loss: 4.464e-04, Remain time: 1.4 min
# Epoch 1350/1500, Training Loss: 1.125e-04, Remain time: 1.3 min
# Epoch 1360/1500, Training Loss: 1.717e-04, Remain time: 1.3 min
# Epoch 1370/1500, Training Loss: 1.313e-04, Remain time: 1.1 min
# Epoch 1380/1500, Training Loss: 1.085e-04, Remain time: 1.0 min
# Epoch 1390/1500, Training Loss: 1.544e-04, Remain time: 1.0 min
# Epoch 1400/1500, Training Loss: 1.374e-04, Remain time: 0.9 min
# Epoch 1410/1500, Training Loss: 1.005e-04, Remain time: 0.8 min
# Epoch 1420/1500, Training Loss: 1.355e-04, Remain time: 0.7 min
# Epoch 1430/1500, Training Loss: 2.509e-04, Remain time: 0.6 min
# Epoch 1440/1500, Training Loss: 2.325e-03, Remain time: 0.5 min
# Epoch 1450/1500, Training Loss: 8.386e-05, Remain time: 0.4 min
# Epoch 1460/1500, Training Loss: 1.916e-04, Remain time: 0.4 min
# Epoch 1470/1500, Training Loss: 1.442e-04, Remain time: 0.3 min
# Epoch 1480/1500, Training Loss: 9.661e-05, Remain time: 0.2 min
# Epoch 1490/1500, Training Loss: 5.670e-04, Remain time: 0.1 min
# Epoch 1500/1500, Training Loss: 1.296e-04, Remain time: 0.0 min

# %% [markdown]
# ## GPU monitor
# ### nvidia-smi -l 3
