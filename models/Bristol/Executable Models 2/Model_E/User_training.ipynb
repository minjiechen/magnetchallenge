# %% [markdown]
# # Env Setting

# %%
model_saved_name="model_colab.ckpt"
dataset_path="data/std_dataset"

# %% [markdown]
# ## Colab

# %%
colab_dir = '/content/drive/MyDrive/DeepLearning/MagNet_Final_test_comb/MagNet_comb_modelB_cycle'  # example for colab

platform = 'auto' # auto detect platform (colab, windows_local, linux_local, unknown)
#platform = 'colab'
#platform = 'windows_local'
#platform = 'linux_local'
#platform = 'unknown'

# %% [markdown]
# ### Path config

# %%
import os

try:
    from google.colab import drive
    drive.mount("/content/drive")
except ImportError:
    if os.path.exists('c:/'):  # check if it is windows
        platform = 'windows_local'
    elif os.path.exists('/home/'):  # check if it is linux
        platform = 'linux_local'
    else:
        platform = 'unknown'
else:
    platform = 'colab'

if platform == 'colab':
  os.chdir(colab_dir)

print('\ncurrent execution path: ', os.getcwd())  #获取当前工作目录路径
print('\ncurrent platform: ', platform)  #获取当前工作目录路径
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# current execution path:  /content/drive/MyDrive/DeepLearning/MagNet_Final_test_comb/MagNet_comb_modelA_cycle
#
# current platform:  colab

# %% [markdown]
# # Cuda check

# %%
import torch

gpu_num = 0
cuda_ready = False

if torch.cuda.is_available():
    cuda_ready = True
    print('cuda good!')
    gpu_num = torch.cuda.device_count()
    if (gpu_num < 1):
        print('GPU unavailable')
    else:
        print('GPU num: ', gpu_num)  # 查看GPU数量
        for gpu in range(gpu_num):
            print('GPU type: ', torch.cuda.get_device_name(gpu))  # 查看GPU名称
            print('GPU memory: {:.2f} Gbyte'.format(
                torch.cuda.get_device_properties(gpu).total_memory /
                1e9))  # 查看GPU总内存
else:
    cuda_ready = False
    print('cuda unavailable!')
# Out:
# cuda good!
# GPU num:  1
# GPU type:  Tesla T4
# GPU memory: 15.84 Gbyte

# %% [markdown]
# # Start coding

# %%
print(platform)
print(os.getcwd())
print(cuda_ready)
print(os.path.abspath(''))
# Out:
# colab
# /content/drive/MyDrive/DeepLearning/MagNet_Final_test_comb/MagNet_comb_modelA_cycle
# True
# /content/drive/MyDrive/DeepLearning/MagNet_Final_test_comb/MagNet_comb_modelA_cycle

# %%
import numpy as np
import torch
import torch.optim as optim
import torch.nn as nn
import matplotlib.pyplot as plt


import NW_LSTM
import NN_DataLoader

# %%
# Check if CUDA is available and if so, set the device to GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#device = torch.device("cpu")
print("Device using ",device)

# Instantiate the model with appropriate dimensions
model = model = NW_LSTM.get_global_model().to(device)

# Print the model architecture and parameters number
print(model)
print("Total number of parameters: ", sum(p.numel() for p in model.parameters()))

# Load the pre-train model if it exists
try:
    model.load_state_dict(torch.load(model_saved_name))
    print("Pre-train model loaded")
except:
    print("No model found, start training from scratch")
    pass

# Define the loss function and optimizer
#loss_fn = nn.MSELoss()
loss_fn = NW_LSTM.RelativeLoss()
#loss_fn = NW_LSTM.RelativeLoss_abs()
optimizer = optim.AdamW(model.parameters(), lr=1e-4)

# lr scheduler
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=1, last_epoch=-1)
#scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200, eta_min=0, last_epoch=-1)
# Out:
# Device using  cuda
# LSTMSeq2One(
#   (lstm): LSTM(1, 30, num_layers=3, batch_first=True)
#   (fc1): Linear(in_features=32, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=196, bias=True)
#   (fc3): Linear(in_features=196, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=96, bias=True)
#   (fc5): Linear(in_features=96, out_features=32, bias=True)
#   (fc6): Linear(in_features=32, out_features=32, bias=True)
#   (fc7): Linear(in_features=32, out_features=16, bias=True)
#   (fc8): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
#   (leaky_relu): LeakyReLU(negative_slope=0.01)
#   (elu): ELU(alpha=1.0)
#   (sigmoid): Sigmoid()
# )
# Total number of parameters:  90653
# Pre-train model loaded

# %%
# Default para in desktop env
epochs = 10
valid_batch_size=1000

if platform == "colab":
  epochs = 1500
  valid_batch_size=2000


train_dataloader = NN_DataLoader.get_dataLoader(os.path.normpath(dataset_path +
                                                            "/train.mat"),
                                          batch_size=128)

# Get validation data
valid_dataloader = NN_DataLoader.get_dataLoader(os.path.normpath(dataset_path +
                                                            "/valid.mat"),
                                            batch_size=valid_batch_size)
valid_inputs, valid_targets = next(iter(valid_dataloader))
valid_inputs, valid_targets = valid_inputs.to(device), valid_targets.to(device)



# estimate time used for training
import time
t0 = time.perf_counter()

# Save the model with the lowest validation loss
with torch.no_grad():
    valid_outputs = model(valid_inputs)
    # Compute loss
    minium_loss = loss_fn(valid_outputs, valid_targets)

# Train the model
for epoch in range(epochs):


    # estimate time used for one epoch(s)
    t_epoch = time.perf_counter() - t0
    t0 = time.perf_counter()

    # Train one epoch
    for i, (train_inputs, train_targets) in enumerate(train_dataloader):
        # Move data to device
        train_inputs, train_targets = train_inputs.to(device), train_targets.to(device)

        # Forward pass
        train_outputs = model(train_inputs)

        # Compute loss
        loss = loss_fn(train_outputs, train_targets)

        # Backward pass and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Compute validation loss
    if epoch > 100:
        with torch.no_grad():
            valid_outputs = model(valid_inputs)
            # Compute loss
            valid_loss = loss_fn(valid_outputs, valid_targets)

        if valid_loss < minium_loss:
            minium_loss = valid_loss
            torch.save(model.state_dict(), model_saved_name)
            print(f"  Model saved , Validation Loss: {valid_loss.item():.3e}, lr: {optimizer.param_groups[0]['lr']:.3e}")

    # update lr
    scheduler.step()

    # Print loss every 10 epochs
    if (epoch + 1) % 10 == 0:
        print(f"Epoch {epoch + 1}/{epochs}, Training Loss: {loss.item():.3e}, "
            #   f"Validation Loss: {valid_loss.item():.3e} ,"
              f"Remain time: {t_epoch/60 * (epochs - epoch - 1):.1f} min")
# Out:
# Epoch 10/1500, Training Loss: 2.072e-02, Remain time: 2.4 min
# Epoch 20/1500, Training Loss: 2.056e-02, Remain time: 2.6 min
# Epoch 30/1500, Training Loss: 1.692e-02, Remain time: 1.6 min
# Epoch 40/1500, Training Loss: 1.909e-02, Remain time: 1.8 min
# Epoch 50/1500, Training Loss: 1.068e-01, Remain time: 1.7 min
# Epoch 60/1500, Training Loss: 1.642e-01, Remain time: 1.7 min
# Epoch 70/1500, Training Loss: 2.628e-02, Remain time: 1.7 min
# Epoch 80/1500, Training Loss: 1.892e-02, Remain time: 1.6 min
# Epoch 90/1500, Training Loss: 1.311e-02, Remain time: 1.6 min
# Epoch 100/1500, Training Loss: 1.358e-02, Remain time: 1.6 min
#   Model saved , Validation Loss: 1.911e-02, lr: 1.000e-04
#   Model saved , Validation Loss: 1.881e-02, lr: 1.000e-04
#   Model saved , Validation Loss: 1.869e-02, lr: 1.000e-04
#   Model saved , Validation Loss: 1.850e-02, lr: 1.000e-04
# Epoch 110/1500, Training Loss: 1.603e-02, Remain time: 1.7 min
# Epoch 120/1500, Training Loss: 1.159e-01, Remain time: 1.8 min
# Epoch 130/1500, Training Loss: 6.381e-02, Remain time: 1.6 min
# Epoch 140/1500, Training Loss: 2.985e-02, Remain time: 1.6 min
# Epoch 150/1500, Training Loss: 2.077e-02, Remain time: 1.6 min
#   Model saved , Validation Loss: 1.823e-02, lr: 1.000e-04
# Epoch 160/1500, Training Loss: 1.922e-02, Remain time: 1.7 min
# Epoch 170/1500, Training Loss: 1.561e-02, Remain time: 2.3 min
# Epoch 180/1500, Training Loss: 1.030e-02, Remain time: 2.3 min
# Epoch 190/1500, Training Loss: 6.105e-02, Remain time: 2.5 min
#   Model saved , Validation Loss: 1.815e-02, lr: 1.000e-04
# Epoch 200/1500, Training Loss: 1.226e-02, Remain time: 2.1 min
# Epoch 210/1500, Training Loss: 1.736e-02, Remain time: 2.0 min
#   Model saved , Validation Loss: 1.797e-02, lr: 1.000e-04
# Epoch 220/1500, Training Loss: 5.860e-03, Remain time: 2.2 min
#   Model saved , Validation Loss: 1.791e-02, lr: 1.000e-04
#   Model saved , Validation Loss: 1.762e-02, lr: 1.000e-04
# Epoch 230/1500, Training Loss: 9.056e-03, Remain time: 1.7 min
# Epoch 240/1500, Training Loss: 2.769e-02, Remain time: 1.4 min
# Epoch 250/1500, Training Loss: 3.085e-02, Remain time: 1.4 min
# Epoch 260/1500, Training Loss: 3.913e-02, Remain time: 1.4 min
#   Model saved , Validation Loss: 1.762e-02, lr: 1.000e-04
# Epoch 270/1500, Training Loss: 1.765e-02, Remain time: 1.7 min
# Epoch 280/1500, Training Loss: 2.317e-02, Remain time: 1.4 min
# Epoch 290/1500, Training Loss: 4.299e-02, Remain time: 1.4 min
# Epoch 300/1500, Training Loss: 1.768e-02, Remain time: 1.4 min
#   Model saved , Validation Loss: 1.760e-02, lr: 1.000e-04
# Epoch 310/1500, Training Loss: 1.227e-02, Remain time: 1.5 min
# Epoch 320/1500, Training Loss: 1.734e-02, Remain time: 1.4 min
#   Model saved , Validation Loss: 1.735e-02, lr: 1.000e-04
#   Model saved , Validation Loss: 1.731e-02, lr: 1.000e-04
# Epoch 330/1500, Training Loss: 1.870e-02, Remain time: 1.5 min
#   Model saved , Validation Loss: 1.718e-02, lr: 1.000e-04
# Epoch 340/1500, Training Loss: 1.049e-02, Remain time: 1.3 min
#   Model saved , Validation Loss: 1.709e-02, lr: 1.000e-04
# Epoch 350/1500, Training Loss: 1.509e-02, Remain time: 1.3 min
# Epoch 360/1500, Training Loss: 3.903e-02, Remain time: 2.0 min
#   Model saved , Validation Loss: 1.690e-02, lr: 1.000e-04
#   Model saved , Validation Loss: 1.687e-02, lr: 1.000e-04
# Epoch 370/1500, Training Loss: 1.618e-02, Remain time: 2.0 min
#   Model saved , Validation Loss: 1.673e-02, lr: 1.000e-04
# Epoch 380/1500, Training Loss: 8.342e-03, Remain time: 1.9 min
# Epoch 390/1500, Training Loss: 1.326e-02, Remain time: 1.9 min
# Epoch 400/1500, Training Loss: 3.513e-02, Remain time: 1.8 min
# Epoch 410/1500, Training Loss: 1.576e-02, Remain time: 1.8 min
# Epoch 420/1500, Training Loss: 4.711e-01, Remain time: 1.3 min
# Epoch 430/1500, Training Loss: 1.505e-02, Remain time: 1.4 min
#   Model saved , Validation Loss: 1.629e-02, lr: 1.000e-04
#   Model saved , Validation Loss: 1.621e-02, lr: 1.000e-04
# Epoch 440/1500, Training Loss: 1.294e-02, Remain time: 1.4 min
# Epoch 450/1500, Training Loss: 1.196e-02, Remain time: 1.2 min
# Epoch 460/1500, Training Loss: 9.460e-03, Remain time: 1.2 min
#   Model saved , Validation Loss: 1.601e-02, lr: 1.000e-04
# Epoch 470/1500, Training Loss: 1.950e-02, Remain time: 1.2 min
# Epoch 480/1500, Training Loss: 2.184e-02, Remain time: 1.1 min
# Epoch 490/1500, Training Loss: 6.267e-03, Remain time: 1.2 min
# Epoch 500/1500, Training Loss: 1.382e-02, Remain time: 1.1 min
# Epoch 510/1500, Training Loss: 1.182e-01, Remain time: 1.1 min
# Epoch 520/1500, Training Loss: 1.185e-02, Remain time: 1.2 min
# Epoch 530/1500, Training Loss: 1.070e-02, Remain time: 1.2 min
#   Model saved , Validation Loss: 1.584e-02, lr: 1.000e-04
#   Model saved , Validation Loss: 1.546e-02, lr: 1.000e-04
# Epoch 540/1500, Training Loss: 1.419e-02, Remain time: 1.1 min
#   Model saved , Validation Loss: 1.542e-02, lr: 1.000e-04
# Epoch 550/1500, Training Loss: 1.345e-02, Remain time: 1.1 min
# Epoch 560/1500, Training Loss: 2.546e-02, Remain time: 1.6 min
#   Model saved , Validation Loss: 1.524e-02, lr: 1.000e-04
# Epoch 570/1500, Training Loss: 7.704e-03, Remain time: 1.5 min
# Epoch 580/1500, Training Loss: 1.364e-02, Remain time: 1.5 min
#   Model saved , Validation Loss: 1.499e-02, lr: 1.000e-04
# Epoch 590/1500, Training Loss: 9.946e-03, Remain time: 1.6 min
#   Model saved , Validation Loss: 1.499e-02, lr: 1.000e-04
# Epoch 600/1500, Training Loss: 1.430e-02, Remain time: 1.5 min
# Epoch 610/1500, Training Loss: 1.305e-02, Remain time: 1.5 min
#   Model saved , Validation Loss: 1.494e-02, lr: 1.000e-04
#   Model saved , Validation Loss: 1.479e-02, lr: 1.000e-04
# Epoch 620/1500, Training Loss: 6.307e-03, Remain time: 1.2 min
#   Model saved , Validation Loss: 1.466e-02, lr: 1.000e-04
#   Model saved , Validation Loss: 1.427e-02, lr: 1.000e-04
# Epoch 630/1500, Training Loss: 4.934e-03, Remain time: 1.1 min
# Epoch 640/1500, Training Loss: 1.472e-02, Remain time: 1.0 min
# Epoch 650/1500, Training Loss: 7.431e-03, Remain time: 1.0 min
# Epoch 660/1500, Training Loss: 1.690e-02, Remain time: 1.0 min
# Epoch 670/1500, Training Loss: 2.735e-02, Remain time: 0.9 min
# Epoch 680/1500, Training Loss: 1.390e-02, Remain time: 1.0 min
# Epoch 690/1500, Training Loss: 1.303e-02, Remain time: 0.9 min
# Epoch 700/1500, Training Loss: 1.648e-02, Remain time: 0.9 min
# Epoch 710/1500, Training Loss: 7.834e-03, Remain time: 0.9 min
# Epoch 720/1500, Training Loss: 1.340e-02, Remain time: 1.0 min
# Epoch 730/1500, Training Loss: 1.493e-02, Remain time: 0.9 min
# Epoch 740/1500, Training Loss: 6.150e-03, Remain time: 0.9 min
# Epoch 750/1500, Training Loss: 1.852e-02, Remain time: 0.9 min
#   Model saved , Validation Loss: 1.392e-02, lr: 1.000e-04
#   Model saved , Validation Loss: 1.347e-02, lr: 1.000e-04
# Epoch 760/1500, Training Loss: 5.032e-03, Remain time: 1.3 min
#   Model saved , Validation Loss: 1.331e-02, lr: 1.000e-04
# Epoch 770/1500, Training Loss: 1.021e-02, Remain time: 1.4 min
# Epoch 780/1500, Training Loss: 7.520e-03, Remain time: 1.3 min
# Epoch 790/1500, Training Loss: 9.970e-03, Remain time: 1.4 min
#   Model saved , Validation Loss: 1.300e-02, lr: 1.000e-04
#   Model saved , Validation Loss: 1.279e-02, lr: 1.000e-04
# Epoch 800/1500, Training Loss: 8.997e-03, Remain time: 1.2 min
# Epoch 810/1500, Training Loss: 4.636e-02, Remain time: 1.2 min
# Epoch 820/1500, Training Loss: 5.051e-02, Remain time: 0.8 min
# Epoch 830/1500, Training Loss: 2.134e-02, Remain time: 0.8 min
# Epoch 840/1500, Training Loss: 1.479e-02, Remain time: 0.8 min
# Epoch 850/1500, Training Loss: 9.056e-03, Remain time: 0.7 min
#   Model saved , Validation Loss: 1.274e-02, lr: 1.000e-04
#   Model saved , Validation Loss: 1.268e-02, lr: 1.000e-04
# Epoch 860/1500, Training Loss: 1.034e-02, Remain time: 0.8 min
# Epoch 870/1500, Training Loss: 4.340e-02, Remain time: 0.7 min
#   Model saved , Validation Loss: 1.258e-02, lr: 1.000e-04
#   Model saved , Validation Loss: 1.237e-02, lr: 1.000e-04
# Epoch 880/1500, Training Loss: 1.109e-02, Remain time: 0.8 min
#   Model saved , Validation Loss: 1.233e-02, lr: 1.000e-04
# Epoch 890/1500, Training Loss: 1.632e-02, Remain time: 0.7 min
# Epoch 900/1500, Training Loss: 1.880e-02, Remain time: 0.7 min
#   Model saved , Validation Loss: 1.214e-02, lr: 1.000e-04
# Epoch 910/1500, Training Loss: 8.595e-03, Remain time: 0.7 min
# Epoch 920/1500, Training Loss: 6.640e-03, Remain time: 0.7 min
# Epoch 930/1500, Training Loss: 1.323e-02, Remain time: 0.7 min
#   Model saved , Validation Loss: 1.184e-02, lr: 1.000e-04
#   Model saved , Validation Loss: 1.161e-02, lr: 1.000e-04
# Epoch 940/1500, Training Loss: 1.115e-02, Remain time: 0.7 min
# Epoch 950/1500, Training Loss: 7.002e-03, Remain time: 1.0 min
# Epoch 960/1500, Training Loss: 4.675e-03, Remain time: 0.9 min
# Epoch 970/1500, Training Loss: 2.629e-02, Remain time: 0.9 min
# Epoch 980/1500, Training Loss: 7.416e-03, Remain time: 0.9 min
# Epoch 990/1500, Training Loss: 8.883e-03, Remain time: 0.8 min
# Epoch 1000/1500, Training Loss: 1.017e-02, Remain time: 0.8 min
# Epoch 1010/1500, Training Loss: 1.054e-02, Remain time: 0.6 min
#   Model saved , Validation Loss: 1.103e-02, lr: 1.000e-04
# Epoch 1020/1500, Training Loss: 1.889e-02, Remain time: 0.6 min
# Epoch 1030/1500, Training Loss: 6.957e-03, Remain time: 0.6 min
#   Model saved , Validation Loss: 1.096e-02, lr: 1.000e-04
#   Model saved , Validation Loss: 1.077e-02, lr: 1.000e-04
# Epoch 1040/1500, Training Loss: 7.914e-03, Remain time: 0.5 min
# Epoch 1050/1500, Training Loss: 9.575e-02, Remain time: 0.5 min
# Epoch 1060/1500, Training Loss: 8.607e-03, Remain time: 0.5 min
#   Model saved , Validation Loss: 1.056e-02, lr: 1.000e-04
# Epoch 1070/1500, Training Loss: 5.214e-03, Remain time: 0.5 min
# Epoch 1080/1500, Training Loss: 7.833e-03, Remain time: 0.5 min
# Epoch 1090/1500, Training Loss: 1.186e-01, Remain time: 0.5 min
# Epoch 1100/1500, Training Loss: 5.215e-02, Remain time: 0.5 min
# Epoch 1110/1500, Training Loss: 7.911e-03, Remain time: 0.4 min
#   Model saved , Validation Loss: 1.045e-02, lr: 1.000e-04
# Epoch 1120/1500, Training Loss: 1.004e-02, Remain time: 0.4 min
# Epoch 1130/1500, Training Loss: 9.648e-03, Remain time: 0.5 min
#   Model saved , Validation Loss: 1.044e-02, lr: 1.000e-04
#   Model saved , Validation Loss: 1.030e-02, lr: 1.000e-04
#   Model saved , Validation Loss: 1.020e-02, lr: 1.000e-04
#   Model saved , Validation Loss: 1.016e-02, lr: 1.000e-04
# Epoch 1140/1500, Training Loss: 4.365e-03, Remain time: 0.5 min
# Epoch 1150/1500, Training Loss: 7.710e-03, Remain time: 0.6 min
#   Model saved , Validation Loss: 1.013e-02, lr: 1.000e-04
# Epoch 1160/1500, Training Loss: 8.096e-03, Remain time: 0.6 min
#   Model saved , Validation Loss: 9.889e-03, lr: 1.000e-04
# Epoch 1170/1500, Training Loss: 1.040e-02, Remain time: 0.6 min
# Epoch 1180/1500, Training Loss: 1.064e-02, Remain time: 0.5 min
#   Model saved , Validation Loss: 9.763e-03, lr: 1.000e-04
# Epoch 1190/1500, Training Loss: 4.447e-03, Remain time: 0.5 min
#   Model saved , Validation Loss: 9.753e-03, lr: 1.000e-04
#   Model saved , Validation Loss: 9.545e-03, lr: 1.000e-04
# Epoch 1200/1500, Training Loss: 7.470e-03, Remain time: 0.5 min
#   Model saved , Validation Loss: 9.489e-03, lr: 1.000e-04
# Epoch 1210/1500, Training Loss: 8.489e-03, Remain time: 0.3 min
# Epoch 1220/1500, Training Loss: 9.144e-03, Remain time: 0.3 min
# Epoch 1230/1500, Training Loss: 1.523e-02, Remain time: 0.3 min
# Epoch 1240/1500, Training Loss: 7.147e-03, Remain time: 0.3 min
# Epoch 1250/1500, Training Loss: 1.248e-02, Remain time: 0.3 min
#   Model saved , Validation Loss: 9.418e-03, lr: 1.000e-04
# Epoch 1260/1500, Training Loss: 4.433e-03, Remain time: 0.3 min
#   Model saved , Validation Loss: 9.325e-03, lr: 1.000e-04
# Epoch 1270/1500, Training Loss: 5.123e-03, Remain time: 0.3 min
# Epoch 1280/1500, Training Loss: 8.486e-03, Remain time: 0.3 min
# Epoch 1290/1500, Training Loss: 1.146e-02, Remain time: 0.3 min
# Epoch 1300/1500, Training Loss: 5.534e-03, Remain time: 0.2 min
#   Model saved , Validation Loss: 9.022e-03, lr: 1.000e-04
# Epoch 1310/1500, Training Loss: 2.217e-02, Remain time: 0.2 min
# Epoch 1320/1500, Training Loss: 1.046e-02, Remain time: 0.2 min
# Epoch 1330/1500, Training Loss: 8.037e-03, Remain time: 0.2 min
#   Model saved , Validation Loss: 8.850e-03, lr: 1.000e-04
#   Model saved , Validation Loss: 8.840e-03, lr: 1.000e-04
# Epoch 1340/1500, Training Loss: 7.610e-03, Remain time: 0.2 min
# Epoch 1350/1500, Training Loss: 2.094e-02, Remain time: 0.2 min
# Epoch 1360/1500, Training Loss: 2.789e-03, Remain time: 0.2 min
#   Model saved , Validation Loss: 8.547e-03, lr: 1.000e-04
# Epoch 1370/1500, Training Loss: 8.773e-03, Remain time: 0.2 min
# Epoch 1380/1500, Training Loss: 6.119e-03, Remain time: 0.2 min
# Epoch 1390/1500, Training Loss: 1.881e-02, Remain time: 0.2 min
# Epoch 1400/1500, Training Loss: 9.657e-03, Remain time: 0.2 min
# Epoch 1410/1500, Training Loss: 6.488e-03, Remain time: 0.1 min
# Epoch 1420/1500, Training Loss: 1.316e-02, Remain time: 0.1 min
# Epoch 1430/1500, Training Loss: 2.099e-02, Remain time: 0.1 min
# Epoch 1440/1500, Training Loss: 5.765e-03, Remain time: 0.1 min
#   Model saved , Validation Loss: 8.116e-03, lr: 1.000e-04
# Epoch 1450/1500, Training Loss: 1.311e-02, Remain time: 0.1 min
# Epoch 1460/1500, Training Loss: 4.708e-03, Remain time: 0.0 min
# Epoch 1470/1500, Training Loss: 5.343e-03, Remain time: 0.0 min
# Epoch 1480/1500, Training Loss: 4.022e-03, Remain time: 0.0 min
# Epoch 1490/1500, Training Loss: 3.951e-03, Remain time: 0.0 min
# Epoch 1500/1500, Training Loss: 1.083e-02, Remain time: 0.0 min

# %% [markdown]
# ## GPU monitor
# ### nvidia-smi -l 3
