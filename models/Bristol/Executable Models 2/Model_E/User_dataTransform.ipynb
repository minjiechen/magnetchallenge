# %%
from dataTransform import *
from Maglib import *

# %% [markdown]
# # Path setting

# %%
raw_data = Maglib.MagLoader(
    r"G:\我的云端硬盘\DeepLearning\Challenge\Challenge_Training_Ratio\Material E",
    'numpy',
    'csv',
    )

# raw_data = Maglib.MagLoader(
#     r"D:\Code_Repository\MagNet_raw_data\Processed\N87_cycle.mat"
#     )
newStep=128
savePath = r"data\std_dataset"

# path using \ instead of /

# %% [markdown]
# # Process

# %%
raw_data=dataTransform(raw_data, newStep, savePath)
dataSplit(raw_data, savePath)
print("Done")
import os
print("Data saved in \n"+os.path.abspath(savePath))
# Out:
# Data transform done
# DataSplit done
# Done
# Data saved in
# g:\我的云端硬盘\DeepLearning\Grp_Small\TL\MagNet_small_modelE_cycle\data\std_dataset
