# %% [markdown]
# # User Colab Path Setting

# %%
colab_dir = '/content/drive/MyDrive/DeepLearning/Challange_comb_shift_flip/MagNet_comb_modelD_cycle'  # example for colab

platform = 'auto' # auto detect platform (colab, windows_local, linux_local, unknown)
#platform = 'colab'
#platform = 'windows_local'
#platform = 'linux_local'
#platform = 'unknown'

# %% [markdown]
# # Trainnig process

# %% [markdown]
# ### Defult path config

# %%
model_saved_name="model_tl.ckpt"
dataset_path="data/tl_dataset"

# %% [markdown]
# ### Path config

# %%
import os

try:
    from google.colab import drive
    drive.mount("/content/drive")
except ImportError:
    if os.path.exists('c:/'):  # check if it is windows
        platform = 'windows_local'
    elif os.path.exists('/home/'):  # check if it is linux
        platform = 'linux_local'
    else:
        platform = 'unknown'
else:
    platform = 'colab'

if platform == 'colab':
  os.chdir(colab_dir)

print('\ncurrent execution path: ', os.getcwd())  #获取当前工作目录路径
print('\ncurrent platform: ', platform)  #获取当前工作目录路径
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# current execution path:  /content/drive/MyDrive/DeepLearning/Challange_comb_shift_flip/MagNet_comb_modelD_cycle
#
# current platform:  colab

# %% [markdown]
# ## Cuda check

# %%
import torch

gpu_num = 0
cuda_ready = False

if torch.cuda.is_available():
    cuda_ready = True
    print('cuda good!')
    gpu_num = torch.cuda.device_count()
    if (gpu_num < 1):
        print('GPU unavailable')
    else:
        print('GPU num: ', gpu_num)  # 查看GPU数量
        for gpu in range(gpu_num):
            print('GPU type: ', torch.cuda.get_device_name(gpu))  # 查看GPU名称
            print('GPU memory: {:.2f} Gbyte'.format(
                torch.cuda.get_device_properties(gpu).total_memory /
                1e9))  # 查看GPU总内存
else:
    cuda_ready = False
    print('cuda unavailable!')
# Out:
# cuda good!
# GPU num:  1
# GPU type:  Tesla V100-SXM2-16GB
# GPU memory: 16.94 Gbyte

# %% [markdown]
# ## Start coding

# %%
print(platform)
print(os.getcwd())
print(cuda_ready)
print(os.path.abspath(''))
# Out:
# colab
# /content/drive/MyDrive/DeepLearning/Challange_comb_shift_flip/MagNet_comb_modelD_cycle
# True
# /content/drive/MyDrive/DeepLearning/Challange_comb_shift_flip/MagNet_comb_modelD_cycle

# %%
import numpy as np
import torch
import torch.optim as optim
import torch.nn as nn
import matplotlib.pyplot as plt


import NW_LSTM
import NN_DataLoader

# %%
# Check if CUDA is available and if so, set the device to GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#device = torch.device("cpu")
print("Device using ",device)

# Instantiate the model with appropriate dimensions
model = model = NW_LSTM.get_global_model().to(device)

# Print the model architecture and parameters number
print(model)
print("Total number of parameters: ", sum(p.numel() for p in model.parameters()))
# Out:
# Device using  cuda
# LSTMSeq2One(
#   (lstm): LSTM(1, 30, num_layers=3, batch_first=True)
#   (fc1): Linear(in_features=32, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=196, bias=True)
#   (fc3): Linear(in_features=196, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=96, bias=True)
#   (fc5): Linear(in_features=96, out_features=32, bias=True)
#   (fc6): Linear(in_features=32, out_features=32, bias=True)
#   (fc7): Linear(in_features=32, out_features=16, bias=True)
#   (fc8): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
#   (leaky_relu): LeakyReLU(negative_slope=0.01)
#   (elu): ELU(alpha=1.0)
#   (sigmoid): Sigmoid()
# )
# Total number of parameters:  90653

# %% [markdown]
# ### Define training para

# %%
def train_model(epoch_num=700,lr=2e-4,method="forward"):

    # Define the loss function and optimizer
    #loss_fn = nn.MSELoss()
    loss_fn = NW_LSTM.RelativeLoss()
    #loss_fn = NW_LSTM.RelativeLoss_abs()
    optimizer = optim.AdamW(model.parameters(), lr=lr)

    # lr scheduler
    #scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=1, last_epoch=-1)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200, eta_min=0, last_epoch=-1)

    # Default para in desktop env
    epochs = 10
    valid_batch_size=1000

    if platform == "colab":
      epochs = epoch_num
      valid_batch_size=3000


    train_dataloader = NN_DataLoader.get_dataLoader(os.path.normpath(dataset_path +
                                                                "/train.mat"),
                                            batch_size=128)

    # Get validation data
    valid_dataloader = NN_DataLoader.get_dataLoader(os.path.normpath(dataset_path +
                                                                "/valid.mat"),
                                                batch_size=valid_batch_size)
    valid_inputs, valid_targets = next(iter(valid_dataloader))
    valid_inputs, valid_targets = valid_inputs.to(device), valid_targets.to(device)

    # Load the pre-train model if it exists
    try:
      model.load_state_dict(torch.load(model_saved_name))
      print("Pre-train model loaded")
    except:
      print("No model found, start training from scratch")
      pass



    # estimate time used for training
    import time
    t0 = time.perf_counter()

    # Save the model with the lowest validation loss
    with torch.no_grad():
        valid_outputs = model(valid_inputs)
        # Compute loss
        minium_loss = loss_fn(valid_outputs, valid_targets)

    # Train the model
    for epoch in range(epochs):


        # estimate time used for one epoch(s)
        t_epoch = time.perf_counter() - t0
        t0 = time.perf_counter()

        # Train one epoch
        for i, (train_inputs, train_targets) in enumerate(train_dataloader):
            # Move data to device
            train_inputs, train_targets = train_inputs.to(device), train_targets.to(device)

            # Forward pass
            if method == "forward":
                train_outputs = model(train_inputs)
            elif method == "valid":
                train_outputs = model.valid(train_inputs)

            # Compute loss
            loss = loss_fn(train_outputs, train_targets)

            # Backward pass and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        # Compute validation loss
        if epoch > 0:
            with torch.no_grad():
                valid_outputs = model(valid_inputs)
                # Compute loss
                valid_loss = loss_fn(valid_outputs, valid_targets)

            if valid_loss < minium_loss:
                minium_loss = valid_loss
                torch.save(model.state_dict(), model_saved_name)
                print(f"  Model saved , Validation Loss: {valid_loss.item():.3e}, lr: {optimizer.param_groups[0]['lr']:.3e}")

        # update lr
        scheduler.step()

        # Print loss every 10 epochs
        if (epoch + 1) % 10 == 0:
            print(f"Epoch {epoch + 1}/{epochs}, Training Loss: {loss.item():.3e}, "
                #   f"Validation Loss: {valid_loss.item():.3e} ,"
                f"Remain time: {t_epoch/60 * (epochs - epoch - 1):.1f} min")

# %% [markdown]
# ### Training loop

# %%
#train_model(epoch_num=10,lr=2e-4,method="forward")

# %%
for i in range(1):
  #train_model(epoch_num=1000,lr=1e-3,method="forward")
  train_model(epoch_num=1000,lr=2e-4,method="forward")
  #train_model(epoch_num=280,lr=2e-5,method="forward")
# Out:
# Pre-train model loaded
# Epoch 10/1000, Training Loss: 6.839e-03, Remain time: 3.3 min
# Epoch 20/1000, Training Loss: 3.695e-03, Remain time: 2.7 min
# Epoch 30/1000, Training Loss: 3.656e-03, Remain time: 1.5 min
# Epoch 40/1000, Training Loss: 4.184e-03, Remain time: 1.6 min
#   Model saved , Validation Loss: 1.054e-02, lr: 1.790e-04
# Epoch 50/1000, Training Loss: 3.441e-03, Remain time: 1.5 min
# Epoch 60/1000, Training Loss: 4.158e-03, Remain time: 1.4 min
#   Model saved , Validation Loss: 1.019e-02, lr: 1.482e-04
# Epoch 70/1000, Training Loss: 3.589e-03, Remain time: 1.6 min
# Epoch 80/1000, Training Loss: 3.439e-03, Remain time: 1.3 min
# Epoch 90/1000, Training Loss: 5.980e-03, Remain time: 1.2 min
# Epoch 100/1000, Training Loss: 3.755e-03, Remain time: 1.3 min
# Epoch 110/1000, Training Loss: 4.779e-03, Remain time: 1.7 min
# Epoch 120/1000, Training Loss: 4.641e-03, Remain time: 1.8 min
# Epoch 130/1000, Training Loss: 3.858e-03, Remain time: 1.7 min
# Epoch 140/1000, Training Loss: 2.085e-03, Remain time: 1.8 min
# Epoch 580/1000, Training Loss: 3.264e-03, Remain time: 0.9 min
# Epoch 590/1000, Training Loss: 4.388e-03, Remain time: 0.8 min
# Epoch 600/1000, Training Loss: 2.641e-03, Remain time: 0.9 min
# Epoch 610/1000, Training Loss: 3.766e-03, Remain time: 0.5 min
# Epoch 620/1000, Training Loss: 2.787e-03, Remain time: 0.5 min
# Epoch 630/1000, Training Loss: 3.306e-03, Remain time: 0.5 min
# Epoch 640/1000, Training Loss: 3.656e-03, Remain time: 0.5 min
# Epoch 650/1000, Training Loss: 3.435e-03, Remain time: 0.5 min
# Epoch 660/1000, Training Loss: 3.496e-03, Remain time: 0.5 min
# Epoch 670/1000, Training Loss: 3.607e-03, Remain time: 0.5 min
# Epoch 680/1000, Training Loss: 2.713e-03, Remain time: 0.4 min
# Epoch 690/1000, Training Loss: 2.040e-03, Remain time: 0.4 min
# Epoch 700/1000, Training Loss: 6.709e-03, Remain time: 0.4 min
# Epoch 710/1000, Training Loss: 3.736e-03, Remain time: 0.4 min
# Epoch 720/1000, Training Loss: 4.004e-03, Remain time: 0.6 min
# Epoch 730/1000, Training Loss: 3.570e-03, Remain time: 0.5 min
# Epoch 740/1000, Training Loss: 3.553e-03, Remain time: 0.5 min
# Epoch 750/1000, Training Loss: 2.534e-03, Remain time: 0.6 min
# Epoch 760/1000, Training Loss: 7.090e-03, Remain time: 0.4 min
# Epoch 770/1000, Training Loss: 4.036e-03, Remain time: 0.3 min
# Epoch 780/1000, Training Loss: 5.274e-03, Remain time: 0.3 min
# Epoch 790/1000, Training Loss: 3.979e-03, Remain time: 0.3 min
# Epoch 800/1000, Training Loss: 1.139e-02, Remain time: 0.3 min
# Epoch 810/1000, Training Loss: 7.671e-03, Remain time: 0.3 min
# Epoch 820/1000, Training Loss: 5.671e-03, Remain time: 0.3 min
# Epoch 830/1000, Training Loss: 3.057e-03, Remain time: 0.2 min
# Epoch 840/1000, Training Loss: 5.044e-03, Remain time: 0.2 min
# Epoch 850/1000, Training Loss: 2.286e-03, Remain time: 0.2 min
# Epoch 860/1000, Training Loss: 4.066e-03, Remain time: 0.2 min
# Epoch 870/1000, Training Loss: 2.451e-03, Remain time: 0.3 min
# Epoch 880/1000, Training Loss: 5.112e-03, Remain time: 0.3 min
# Epoch 890/1000, Training Loss: 3.788e-03, Remain time: 0.2 min
# Epoch 900/1000, Training Loss: 3.576e-03, Remain time: 0.2 min
# Epoch 910/1000, Training Loss: 3.578e-03, Remain time: 0.1 min
# Epoch 920/1000, Training Loss: 1.789e-03, Remain time: 0.1 min
# Epoch 930/1000, Training Loss: 4.183e-03, Remain time: 0.1 min
# Epoch 940/1000, Training Loss: 2.358e-03, Remain time: 0.1 min
# Epoch 950/1000, Training Loss: 2.597e-03, Remain time: 0.1 min
# Epoch 960/1000, Training Loss: 2.889e-03, Remain time: 0.1 min
# Epoch 970/1000, Training Loss: 2.260e-03, Remain time: 0.0 min
# Epoch 980/1000, Training Loss: 2.497e-03, Remain time: 0.0 min
# Epoch 990/1000, Training Loss: 3.420e-03, Remain time: 0.0 min
# Epoch 1000/1000, Training Loss: 2.890e-03, Remain time: 0.0 min

# %% [markdown]
# ## GPU monitor
# ### nvidia-smi -l 3
