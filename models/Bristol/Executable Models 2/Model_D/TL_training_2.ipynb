# %% [markdown]
# # User Colab Path Setting

# %%
colab_dir = '/content/drive/MyDrive/DeepLearning/Grp_Small/TL/MagNet_small_modelD_cycle'  # example for colab

platform = 'auto' # auto detect platform (colab, windows_local, linux_local, unknown)
#platform = 'colab'
#platform = 'windows_local'
#platform = 'linux_local'
#platform = 'unknown'

# %% [markdown]
# # Trainnig process

# %% [markdown]
# ### Defult path config

# %%
model_saved_name="model_tl.ckpt"
dataset_path="data/tl_dataset"

# %% [markdown]
# ### Path config

# %%
import os

try:
    from google.colab import drive
    drive.mount("/content/drive")
except ImportError:
    if os.path.exists('c:/'):  # check if it is windows
        platform = 'windows_local'
    elif os.path.exists('/home/'):  # check if it is linux
        platform = 'linux_local'
    else:
        platform = 'unknown'
else:
    platform = 'colab'

if platform == 'colab':
  os.chdir(colab_dir)

print('\ncurrent execution path: ', os.getcwd())  #获取当前工作目录路径
print('\ncurrent platform: ', platform)  #获取当前工作目录路径
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# current execution path:  /content/drive/MyDrive/DeepLearning/Grp_Small/TL/MagNet_small_modelD_cycle
#
# current platform:  colab

# %% [markdown]
# ## Cuda check

# %%
import torch

gpu_num = 0
cuda_ready = False

if torch.cuda.is_available():
    cuda_ready = True
    print('cuda good!')
    gpu_num = torch.cuda.device_count()
    if (gpu_num < 1):
        print('GPU unavailable')
    else:
        print('GPU num: ', gpu_num)  # 查看GPU数量
        for gpu in range(gpu_num):
            print('GPU type: ', torch.cuda.get_device_name(gpu))  # 查看GPU名称
            print('GPU memory: {:.2f} Gbyte'.format(
                torch.cuda.get_device_properties(gpu).total_memory /
                1e9))  # 查看GPU总内存
else:
    cuda_ready = False
    print('cuda unavailable!')
# Out:
# cuda good!
# GPU num:  1
# GPU type:  Tesla V100-SXM2-16GB
# GPU memory: 16.94 Gbyte

# %% [markdown]
# ## Start coding

# %%
print(platform)
print(os.getcwd())
print(cuda_ready)
print(os.path.abspath(''))
# Out:
# colab
# /content/drive/MyDrive/DeepLearning/Grp_Small/TL/MagNet_small_modelD_cycle
# True
# /content/drive/MyDrive/DeepLearning/Grp_Small/TL/MagNet_small_modelD_cycle

# %%
import numpy as np
import torch
import torch.optim as optim
import torch.nn as nn
import matplotlib.pyplot as plt


import NW_LSTM
import NN_DataLoader

# %%
# Check if CUDA is available and if so, set the device to GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#device = torch.device("cpu")
print("Device using ",device)

# Instantiate the model with appropriate dimensions
model = model = NW_LSTM.get_global_model().to(device)

# Print the model architecture and parameters number
print(model)
print("Total number of parameters: ", sum(p.numel() for p in model.parameters()))

# Load the pre-train model if it exists
try:
    model.load_state_dict(torch.load(model_saved_name))
    print("Pre-train model loaded")
except:
    print("No model found, start training from scratch")
    pass
# Out:
# Device using  cuda
# LSTMSeq2One(
#   (lstm): LSTM(3, 30, num_layers=2, batch_first=True)
#   (fc1): Linear(in_features=30, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=16, bias=True)
#   (fc4): Linear(in_features=16, out_features=8, bias=True)
#   (fc5): Linear(in_features=8, out_features=8, bias=True)
#   (fc6): Linear(in_features=8, out_features=1, bias=True)
#   (relu): ReLU()
#   (leaky_relu): LeakyReLU(negative_slope=0.01)
#   (elu): ELU(alpha=1.0)
# )
# Total number of parameters:  16449
# Pre-train model loaded

# %% [markdown]
# ### Define training para

# %%
def train_model(epoch_num=700,lr=2e-4,method="forward"):

    # Define the loss function and optimizer
    #loss_fn = nn.MSELoss()
    loss_fn = NW_LSTM.RelativeLoss()
    #loss_fn = NW_LSTM.RelativeLoss_abs()
    optimizer = optim.AdamW(model.parameters(), lr=lr)

    # lr scheduler
    #scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=1, last_epoch=-1)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100, eta_min=0, last_epoch=-1)

    # Default para in desktop env
    epochs = 10
    valid_batch_size=1000

    if platform == "colab":
      epochs = epoch_num
      valid_batch_size=3000


    train_dataloader = NN_DataLoader.get_dataLoader(os.path.normpath(dataset_path +
                                                                "/train.mat"),
                                            batch_size=128)

    # Get validation data
    valid_dataloader = NN_DataLoader.get_dataLoader(os.path.normpath(dataset_path +
                                                                "/valid.mat"),
                                                batch_size=valid_batch_size)
    valid_inputs, valid_targets = next(iter(valid_dataloader))
    valid_inputs, valid_targets = valid_inputs.to(device), valid_targets.to(device)



    # estimate time used for training
    import time
    t0 = time.perf_counter()

    # Save the model with the lowest validation loss
    with torch.no_grad():
        valid_outputs = model(valid_inputs)
        # Compute loss
        minium_loss = loss_fn(valid_outputs, valid_targets)

    # Train the model
    for epoch in range(epochs):


        # estimate time used for one epoch(s)
        t_epoch = time.perf_counter() - t0
        t0 = time.perf_counter()

        # Train one epoch
        for i, (train_inputs, train_targets) in enumerate(train_dataloader):
            # Move data to device
            train_inputs, train_targets = train_inputs.to(device), train_targets.to(device)

            # Forward pass
            if method == "forward":
                train_outputs = model(train_inputs)
            elif method == "valid":
                train_outputs = model.valid(train_inputs)

            # Compute loss
            loss = loss_fn(train_outputs, train_targets)

            # Backward pass and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        # Compute validation loss
        if epoch > 0:
            with torch.no_grad():
                valid_outputs = model(valid_inputs)
                # Compute loss
                valid_loss = loss_fn(valid_outputs, valid_targets)

            if valid_loss < minium_loss:
                minium_loss = valid_loss
                torch.save(model.state_dict(), model_saved_name)
                print(f"  Model saved , Validation Loss: {valid_loss.item():.3e}, lr: {optimizer.param_groups[0]['lr']:.3e}")

        # update lr
        scheduler.step()

        # Print loss every 10 epochs
        if (epoch + 1) % 10 == 0:
            print(f"Epoch {epoch + 1}/{epochs}, Training Loss: {loss.item():.3e}, "
                #   f"Validation Loss: {valid_loss.item():.3e} ,"
                f"Remain time: {t_epoch/60 * (epochs - epoch - 1):.1f} min")

# %% [markdown]
# ### Training loop

# %%
#train_model(epoch_num=10,lr=2e-4,method="forward")

# %%
#train_model(epoch_num=800,lr=10e-4,method="forward")
train_model(epoch_num=1300,lr=4e-4,method="forward")
# Out:
# Epoch 10/1300, Training Loss: 1.377e-03, Remain time: 10.7 min
# Epoch 20/1300, Training Loss: 1.080e-03, Remain time: 11.1 min
# Epoch 30/1300, Training Loss: 2.770e-03, Remain time: 10.7 min
# Epoch 40/1300, Training Loss: 1.182e-03, Remain time: 10.5 min
# Epoch 50/1300, Training Loss: 1.274e-03, Remain time: 14.3 min
#   Model saved , Validation Loss: 8.507e-04, lr: 1.812e-04
# Epoch 60/1300, Training Loss: 6.443e-04, Remain time: 10.0 min
# Epoch 70/1300, Training Loss: 5.664e-04, Remain time: 10.2 min
# Epoch 80/1300, Training Loss: 8.525e-04, Remain time: 14.8 min
# Epoch 90/1300, Training Loss: 7.178e-04, Remain time: 10.5 min
# Epoch 100/1300, Training Loss: 9.338e-04, Remain time: 11.0 min
# Epoch 110/1300, Training Loss: 7.529e-04, Remain time: 14.8 min
# Epoch 120/1300, Training Loss: 1.121e-03, Remain time: 9.6 min
# Epoch 130/1300, Training Loss: 7.543e-04, Remain time: 13.6 min
# Epoch 140/1300, Training Loss: 1.035e-03, Remain time: 9.3 min
# Epoch 150/1300, Training Loss: 9.123e-04, Remain time: 9.3 min
# Epoch 160/1300, Training Loss: 1.262e-03, Remain time: 12.9 min
# Epoch 170/1300, Training Loss: 1.465e-03, Remain time: 8.9 min
# Epoch 180/1300, Training Loss: 2.595e-03, Remain time: 10.2 min
# Epoch 190/1300, Training Loss: 1.285e-03, Remain time: 9.0 min
# Epoch 200/1300, Training Loss: 8.842e-04, Remain time: 9.0 min
# Epoch 210/1300, Training Loss: 8.430e-04, Remain time: 12.5 min
# Epoch 220/1300, Training Loss: 1.270e-03, Remain time: 8.8 min
# Epoch 230/1300, Training Loss: 9.683e-04, Remain time: 8.8 min
# Epoch 240/1300, Training Loss: 7.724e-04, Remain time: 9.1 min
# Epoch 250/1300, Training Loss: 7.014e-04, Remain time: 8.9 min
# Epoch 260/1300, Training Loss: 9.843e-04, Remain time: 12.8 min
# Epoch 270/1300, Training Loss: 7.733e-04, Remain time: 8.9 min
#   Model saved , Validation Loss: 8.202e-04, lr: 7.742e-05
# Epoch 280/1300, Training Loss: 9.020e-04, Remain time: 8.2 min
# Epoch 290/1300, Training Loss: 8.731e-04, Remain time: 11.4 min
# Epoch 300/1300, Training Loss: 8.664e-04, Remain time: 8.0 min
# Epoch 310/1300, Training Loss: 8.279e-04, Remain time: 8.0 min
# Epoch 320/1300, Training Loss: 1.579e-03, Remain time: 8.4 min
# Epoch 330/1300, Training Loss: 6.203e-04, Remain time: 7.8 min
#   Model saved , Validation Loss: 8.184e-04, lr: 8.244e-05
# Epoch 340/1300, Training Loss: 1.571e-03, Remain time: 11.2 min
# Epoch 350/1300, Training Loss: 9.599e-04, Remain time: 7.9 min
# Epoch 360/1300, Training Loss: 1.530e-03, Remain time: 8.1 min
# Epoch 370/1300, Training Loss: 1.571e-03, Remain time: 10.8 min
# Epoch 380/1300, Training Loss: 8.616e-04, Remain time: 7.8 min
# Epoch 390/1300, Training Loss: 1.305e-03, Remain time: 7.7 min
# Epoch 400/1300, Training Loss: 1.009e-03, Remain time: 7.5 min
# Epoch 410/1300, Training Loss: 1.361e-03, Remain time: 7.1 min
# Epoch 420/1300, Training Loss: 6.795e-04, Remain time: 10.3 min
# Epoch 430/1300, Training Loss: 1.025e-03, Remain time: 7.1 min
# Epoch 440/1300, Training Loss: 1.131e-03, Remain time: 7.2 min
# Epoch 450/1300, Training Loss: 6.480e-04, Remain time: 10.1 min
# Epoch 460/1300, Training Loss: 8.910e-04, Remain time: 6.9 min
# Epoch 470/1300, Training Loss: 1.001e-03, Remain time: 6.9 min
# Epoch 480/1300, Training Loss: 5.848e-04, Remain time: 6.8 min
# Epoch 490/1300, Training Loss: 1.017e-03, Remain time: 6.9 min
#   Model saved , Validation Loss: 8.124e-04, lr: 8.876e-07
# Epoch 500/1300, Training Loss: 5.359e-04, Remain time: 9.2 min
# Epoch 510/1300, Training Loss: 7.872e-04, Remain time: 6.6 min
# Epoch 520/1300, Training Loss: 1.317e-03, Remain time: 6.3 min
# Epoch 530/1300, Training Loss: 1.038e-03, Remain time: 9.1 min
# Epoch 540/1300, Training Loss: 8.475e-04, Remain time: 6.4 min
# Epoch 550/1300, Training Loss: 4.073e-03, Remain time: 6.0 min
# Epoch 560/1300, Training Loss: 1.786e-03, Remain time: 5.9 min
# Epoch 570/1300, Training Loss: 7.912e-04, Remain time: 6.0 min
# Epoch 580/1300, Training Loss: 2.339e-03, Remain time: 8.5 min
# Epoch 590/1300, Training Loss: 8.857e-04, Remain time: 5.9 min
# Epoch 600/1300, Training Loss: 1.600e-03, Remain time: 5.7 min
# Epoch 610/1300, Training Loss: 1.330e-03, Remain time: 8.1 min
# Epoch 620/1300, Training Loss: 1.732e-03, Remain time: 5.6 min
# Epoch 630/1300, Training Loss: 6.822e-04, Remain time: 5.4 min
# Epoch 640/1300, Training Loss: 1.673e-03, Remain time: 5.2 min
# Epoch 650/1300, Training Loss: 1.007e-03, Remain time: 5.3 min
# Epoch 660/1300, Training Loss: 1.332e-03, Remain time: 7.6 min
# Epoch 670/1300, Training Loss: 1.688e-03, Remain time: 5.1 min
# Epoch 680/1300, Training Loss: 8.380e-04, Remain time: 5.2 min
# Epoch 690/1300, Training Loss: 7.095e-04, Remain time: 6.4 min
# Epoch 700/1300, Training Loss: 7.887e-04, Remain time: 5.0 min
#   Model saved , Validation Loss: 8.038e-04, lr: 2.462e-06
# Epoch 710/1300, Training Loss: 9.514e-04, Remain time: 5.9 min
# Epoch 720/1300, Training Loss: 1.754e-03, Remain time: 5.0 min
# Epoch 730/1300, Training Loss: 1.070e-03, Remain time: 4.8 min
# Epoch 740/1300, Training Loss: 6.175e-04, Remain time: 6.4 min
# Epoch 750/1300, Training Loss: 1.532e-03, Remain time: 4.5 min
# Epoch 760/1300, Training Loss: 9.420e-04, Remain time: 4.3 min
# Epoch 770/1300, Training Loss: 2.179e-03, Remain time: 4.3 min
# Epoch 780/1300, Training Loss: 8.761e-04, Remain time: 4.4 min
# Epoch 790/1300, Training Loss: 1.852e-03, Remain time: 5.9 min
# Epoch 800/1300, Training Loss: 1.190e-03, Remain time: 4.0 min
# Epoch 810/1300, Training Loss: 1.505e-03, Remain time: 4.0 min
# Epoch 820/1300, Training Loss: 6.078e-04, Remain time: 5.6 min
# Epoch 830/1300, Training Loss: 8.468e-04, Remain time: 3.8 min
# Epoch 840/1300, Training Loss: 6.540e-04, Remain time: 3.8 min
# Epoch 850/1300, Training Loss: 7.845e-04, Remain time: 3.7 min
# Epoch 860/1300, Training Loss: 1.040e-03, Remain time: 3.7 min
# Epoch 870/1300, Training Loss: 5.137e-04, Remain time: 4.9 min
# Epoch 880/1300, Training Loss: 5.275e-04, Remain time: 3.4 min
# Epoch 890/1300, Training Loss: 1.205e-03, Remain time: 3.5 min
# Epoch 900/1300, Training Loss: 8.876e-04, Remain time: 4.6 min
# Epoch 910/1300, Training Loss: 3.952e-04, Remain time: 3.2 min
#   Model saved , Validation Loss: 8.029e-04, lr: 2.180e-05
# Epoch 920/1300, Training Loss: 1.288e-03, Remain time: 3.0 min
# Epoch 930/1300, Training Loss: 5.320e-04, Remain time: 4.2 min
# Epoch 940/1300, Training Loss: 6.089e-04, Remain time: 3.0 min
# Epoch 950/1300, Training Loss: 1.154e-03, Remain time: 3.3 min
# Epoch 960/1300, Training Loss: 1.344e-03, Remain time: 2.9 min
# Epoch 970/1300, Training Loss: 9.020e-04, Remain time: 2.7 min
# Epoch 980/1300, Training Loss: 1.784e-03, Remain time: 3.6 min
# Epoch 990/1300, Training Loss: 1.099e-03, Remain time: 2.6 min
# Epoch 1000/1300, Training Loss: 1.818e-03, Remain time: 2.5 min
# Epoch 1010/1300, Training Loss: 1.423e-03, Remain time: 2.4 min
# Epoch 1020/1300, Training Loss: 6.581e-04, Remain time: 2.4 min
# Epoch 1030/1300, Training Loss: 1.661e-03, Remain time: 3.3 min
# Epoch 1040/1300, Training Loss: 8.118e-04, Remain time: 2.2 min
# Epoch 1050/1300, Training Loss: 7.263e-04, Remain time: 2.1 min
# Epoch 1060/1300, Training Loss: 8.988e-04, Remain time: 2.8 min
# Epoch 1070/1300, Training Loss: 6.562e-04, Remain time: 1.9 min
#   Model saved , Validation Loss: 7.954e-04, lr: 5.421e-05
# Epoch 1080/1300, Training Loss: 8.786e-04, Remain time: 1.8 min
#   Model saved , Validation Loss: 7.951e-04, lr: 1.903e-05
# Epoch 1090/1300, Training Loss: 8.829e-04, Remain time: 1.8 min
# Epoch 1100/1300, Training Loss: 5.373e-04, Remain time: 1.7 min
#   Model saved , Validation Loss: 7.892e-04, lr: 4.817e-06
# Epoch 1110/1300, Training Loss: 4.426e-04, Remain time: 2.3 min
# Epoch 1120/1300, Training Loss: 5.592e-04, Remain time: 1.5 min
# Epoch 1130/1300, Training Loss: 8.576e-04, Remain time: 1.4 min
# Epoch 1140/1300, Training Loss: 1.110e-03, Remain time: 1.9 min
# Epoch 1150/1300, Training Loss: 8.767e-04, Remain time: 1.2 min
# Epoch 1160/1300, Training Loss: 1.745e-03, Remain time: 1.2 min
# Epoch 1170/1300, Training Loss: 1.322e-03, Remain time: 1.1 min
# Epoch 1180/1300, Training Loss: 3.229e-03, Remain time: 1.0 min
# Epoch 1190/1300, Training Loss: 1.235e-03, Remain time: 1.4 min
# Epoch 1200/1300, Training Loss: 1.820e-03, Remain time: 0.8 min
# Epoch 1210/1300, Training Loss: 2.662e-03, Remain time: 0.8 min
# Epoch 1220/1300, Training Loss: 1.749e-03, Remain time: 0.8 min
# Epoch 1230/1300, Training Loss: 1.081e-03, Remain time: 0.6 min
# Epoch 1240/1300, Training Loss: 7.656e-04, Remain time: 0.7 min
# Epoch 1250/1300, Training Loss: 6.061e-04, Remain time: 0.4 min
# Epoch 1260/1300, Training Loss: 7.712e-04, Remain time: 0.3 min
# Epoch 1270/1300, Training Loss: 7.104e-04, Remain time: 0.4 min
# Epoch 1280/1300, Training Loss: 4.804e-04, Remain time: 0.2 min
# Epoch 1290/1300, Training Loss: 6.403e-04, Remain time: 0.1 min
# Epoch 1300/1300, Training Loss: 8.936e-04, Remain time: 0.0 min

# %% [markdown]
# ## GPU monitor
# ### nvidia-smi -l 3
